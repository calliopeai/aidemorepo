# %% [markdown]
# # Named Entity Recognition (NER)
#
# **Category:** 13-NLP
# **Topic:** Extracting entities from text
#
# ---
#
# ## Learning Objectives
# - Understand NER concepts
# - Use spaCy for NER
# - Train custom NER models
# - Evaluate NER performance

# %%
# %pip install -q spacy pandas transformers
# !python -m spacy download en_core_web_sm

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# NER fundamentals:
# 1. What is Named Entity Recognition
# 2. Common entity types (PERSON, ORG, GPE, DATE)
# 3. BIO tagging scheme
# 4. Applications of NER
# 5. Challenges in NER

# %%
# %%ai $MODEL
# spaCy NER:
# 1. Load spaCy model
# 2. Extract entities from text
# 3. Entity labels and spans
# 4. Visualize with displacy
# 5. Process multiple documents

# %%
# %%ai $MODEL
# Custom entity training with spaCy:
# 1. Prepare training data format
# 2. Create blank model
# 3. Add NER pipeline
# 4. Training loop
# 5. Save and load custom model

# %%
# %%ai $MODEL
# Transformer-based NER:
# 1. HuggingFace NER pipeline
# 2. BERT for token classification
# 3. Compare with spaCy
# 4. Fine-tuning considerations
# 5. Multi-lingual NER

# %%
# %%ai $MODEL
# NER evaluation:
# 1. Precision, Recall, F1 per entity type
# 2. Exact vs partial matching
# 3. seqeval library
# 4. Error analysis
# 5. Improve NER accuracy

# %% [markdown]
# ---
#
# ## Summary
#
# Covered NER:
# - NER concepts
# - spaCy implementation
# - Custom training
# - Transformer models
# - Evaluation metrics
#
# ---
