# %% [markdown]
# # Text Preprocessing
#
# **Category:** 13-NLP
# **Topic:** Preparing text data for NLP
#
# ---
#
# ## Learning Objectives
# - Clean and normalize text
# - Tokenization techniques
# - Stopword removal
# - Stemming and lemmatization

# %%
# %pip install -q nltk spacy pandas numpy

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Text cleaning basics:
# 1. Lowercasing
# 2. Remove punctuation
# 3. Remove numbers
# 4. Remove HTML tags
# 5. Handle special characters and unicode
#
# Create a reusable cleaning function.

# %%
# %%ai $MODEL
# Tokenization methods:
# 1. Word tokenization with NLTK
# 2. Sentence tokenization
# 3. spaCy tokenization
# 4. Subword tokenization (BPE, WordPiece)
# 5. Compare tokenizers on same text

# %%
# %%ai $MODEL
# Stopwords and filtering:
# 1. What are stopwords
# 2. NLTK stopword list
# 3. Custom stopwords
# 4. When NOT to remove stopwords
# 5. Frequency-based filtering

# %%
# %%ai $MODEL
# Stemming vs Lemmatization:
# 1. Porter Stemmer
# 2. Snowball Stemmer
# 3. WordNet Lemmatizer
# 4. spaCy lemmatization
# 5. When to use each

# %%
# %%ai $MODEL
# Build complete preprocessing pipeline:
# 1. Create sklearn-compatible transformer
# 2. Configurable options
# 3. Apply to document collection
# 4. TF-IDF vectorization
# 5. Ready for ML model input

# %% [markdown]
# ---
#
# ## Summary
#
# Covered text preprocessing:
# - Text cleaning
# - Tokenization methods
# - Stopword handling
# - Stemming/Lemmatization
# - Preprocessing pipeline
#
# ---
