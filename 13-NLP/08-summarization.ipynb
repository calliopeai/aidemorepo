# %% [markdown]
# # Text Summarization
#
# **Category:** 13-NLP
# **Topic:** Automatic text summarization
#
# ---
#
# ## Learning Objectives
# - Extractive summarization
# - Abstractive summarization
# - Multi-document summarization
# - Evaluate summaries

# %%
# %pip install -q transformers sumy rouge-score nltk

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Extractive summarization:
# 1. What is extractive summarization
# 2. TextRank algorithm
# 3. Use sumy library
# 4. LSA-based summarization
# 5. Select summary length

# %%
# %%ai $MODEL
# Abstractive summarization:
# 1. What is abstractive summarization
# 2. Load BART/T5 model
# 3. Use summarization pipeline
# 4. Control summary length
# 5. Compare with extractive

# %%
# %%ai $MODEL
# Long document summarization:
# 1. Handle documents > model max length
# 2. Chunk and summarize
# 3. Hierarchical summarization
# 4. LED (Longformer Encoder-Decoder)
# 5. Map-reduce approach

# %%
# %%ai $MODEL
# Multi-document summarization:
# 1. Combine multiple sources
# 2. Handle redundancy
# 3. Extract key points
# 4. Cluster similar content
# 5. Generate coherent summary

# %%
# %%ai $MODEL
# Summary evaluation:
# 1. ROUGE scores (ROUGE-1, ROUGE-2, ROUGE-L)
# 2. BLEU score
# 3. BERTScore
# 4. Human evaluation criteria
# 5. Factual consistency check

# %% [markdown]
# ---
#
# ## Summary
#
# Covered text summarization:
# - Extractive methods
# - Abstractive models
# - Long documents
# - Multi-document
# - Evaluation metrics
#
# ---
