# %% [markdown]
# # Question Answering
#
# **Category:** 13-NLP
# **Topic:** Building QA systems
#
# ---
#
# ## Learning Objectives
# - Extractive QA
# - Generative QA
# - Retrieval-augmented QA
# - Evaluate QA systems

# %%
# %pip install -q transformers torch sentence-transformers

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# QA task types:
# 1. Extractive QA (span extraction)
# 2. Abstractive/Generative QA
# 3. Open-domain vs closed-domain
# 4. Multiple choice QA
# 5. Conversational QA

# %%
# %%ai $MODEL
# Extractive QA with transformers:
# 1. Load QA pipeline
# 2. Provide context and question
# 3. Extract answer span
# 4. Confidence scores
# 5. Handle long contexts

# %%
# %%ai $MODEL
# Build simple retrieval QA:
# 1. Document collection
# 2. Embed documents with sentence-transformers
# 3. Semantic search for relevant docs
# 4. Extract answer from retrieved docs
# 5. End-to-end pipeline

# %%
# %%ai $MODEL
# Generative QA:
# 1. T5 for text-to-text QA
# 2. Generate answers from context
# 3. Handle unanswerable questions
# 4. Compare extractive vs generative
# 5. Combine with retrieval

# %%
# %%ai $MODEL
# QA evaluation:
# 1. Exact Match (EM) metric
# 2. F1 score
# 3. BLEU for generative
# 4. SQuAD evaluation script
# 5. Human evaluation criteria

# %% [markdown]
# ---
#
# ## Summary
#
# Covered Question Answering:
# - QA task types
# - Extractive QA
# - Retrieval QA
# - Generative QA
# - Evaluation metrics
#
# ---
