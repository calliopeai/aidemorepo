# %% [markdown]
# # Sentiment Analysis
#
# **Category:** 13-NLP
# **Topic:** Analyzing text sentiment
#
# ---
#
# ## Learning Objectives
# - Rule-based sentiment analysis
# - ML-based approaches
# - Deep learning methods
# - Aspect-based sentiment

# %%
# %pip install -q nltk textblob transformers scikit-learn pandas

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Rule-based sentiment with VADER:
# 1. What is VADER (Valence Aware Dictionary)
# 2. Install and use nltk.sentiment
# 3. Analyze sample reviews
# 4. Compound score interpretation
# 5. Handles emojis and intensifiers

# %%
# %%ai $MODEL
# TextBlob sentiment:
# 1. Polarity and subjectivity
# 2. Quick sentiment analysis
# 3. Compare with VADER
# 4. Sentence-level analysis
# 5. Limitations

# %%
# %%ai $MODEL
# ML-based sentiment classification:
# 1. Prepare labeled dataset
# 2. TF-IDF features
# 3. Train Naive Bayes classifier
# 4. Train Logistic Regression
# 5. Evaluate and compare

# %%
# %%ai $MODEL
# Transformer-based sentiment:
# 1. Load pre-trained sentiment model
# 2. Use HuggingFace pipeline
# 3. Fine-tune on custom data
# 4. Compare with ML approach
# 5. Deployment considerations

# %%
# %%ai $MODEL
# Aspect-based sentiment:
# 1. What is aspect-based sentiment
# 2. Extract aspects from text
# 3. Sentiment per aspect
# 4. Restaurant review example
# 5. Visualization of results

# %% [markdown]
# ---
#
# ## Summary
#
# Covered sentiment analysis:
# - VADER rule-based
# - TextBlob
# - ML classification
# - Transformers
# - Aspect-based
#
# ---
