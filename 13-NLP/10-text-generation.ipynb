# %%
# =============================================================================
# AUTO-INSTALL DEPENDENCIES
# Run this cell to scan the notebook and install required packages
# =============================================================================
# %%calliope ask claude --format code
Scan this notebook for all Python imports and library dependencies.
Generate a shell script that:
1. Checks if each required package is installed
2. Installs any missing packages using pip
Output only the executable shell commands, no explanations.

# %%
poets = ['Walt Whitman', 'Robert Frost', 'Silvia Plath']
langs = ['python', 'rust', 'javascript']

# %%
# %%ai openai-chat:gpt-4o --format code
# help hme write an jupyter_ai script to iterate commands through both lists  and write in the stype of poets=${poets} and write poems about ${langs}
# Out:
# AI generated code inserted below &#11015;&#65039;

# %%
# Define lists of poets and languages
poets = ["Emily Dickinson", "Robert Frost", "Maya Angelou", "Pablo Neruda"]
langs = ["Python", "JavaScript", "Java", "C++"]

# Iterate through both lists and generate output
for poet in poets:
    for lang in langs:
        print(f"%%ai openai-chat:gpt-4o --format text \n write a poem about {lang} in the style of {poet} \n\n")
# Out:
# %%ai openai-chat:gpt-4o --format text
#  write a poem about Python in the style of Emily Dickinson
#
#
# %%ai openai-chat:gpt-4o --format text
#  write a poem about JavaScript in the style of Emily Dickinson
#
#
# %%ai openai-chat:gpt-4o --format text
#  write a poem about Java in the style of Emily Dickinson
#
#
# %%ai openai-chat:gpt-4o --format text
#  write a poem about C++ in the style of Emily Dickinson
#
#
# %%ai openai-chat:gpt-4o --format text
#  write a poem about Python in the style of Robert Frost
#
#
# %%ai openai-chat:gpt-4o --format text
#  write a poem about JavaScript in the style of Robert Frost
#
#
# %%ai openai-chat:gpt-4o --format text
#  write a poem about Java in the style of Robert Frost
#
#
# %%ai openai-chat:gpt-4o --format text
#  write a poem about C++ in the style of Robert Frost
#
#
# %%ai openai-chat:gpt-4o --format text
#  write a poem about Python in the style of Maya Angelou
#
#
# %%ai openai-chat:gpt-4o --format text
# ...

# %%
# %%ai openai-chat:gpt-4o --format text
#  write a poem about Python in the style of Emily Dickinson
# Out:
# In realms where silence speaks in code,
# A serpent's wisdom weaves its thread,
# With syntax pure, and logic bold,
# A language born where dreams are led.
#
# No need for pomp or grand display,
# Its elegance in whispers lies,
# A world of meaning in array,
# Where loops and functions harmonize.
#
# The whitespace rules, a quiet guide,
# Indentations mark the path we tread,
# And in this space where thoughts reside,
# A universe of wonder's spread.
#
# The import of a library vast,
# A book of knowledge to unfurl,
# Each module tells of futures cast,
# And secrets of the digital world.
#
# Oh, Python, soft and supple tongue,
# The poet's quill in coder's hand,
# In scripts and dreams forever young,
# Where logic meets the heart's command.
#
# In every line, a story spun,
# Where algorithms dance in grace,
# A gentle power, second to none,
# Awakens wonder in this place.

# %%
# %ai register o4 openai-chat:gpt-4o
# Out:
# Registered new alias `o4`

# %%
# %ai register goog gemini:gemini-pro
# Out:
# Registered new alias `goog`

# %%
# %ai register coh cohere:command
# Out:
# Registered new alias `coh`
