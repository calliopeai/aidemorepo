# %% [markdown]
# # Topic Modeling
#
# **Category:** 13-NLP
# **Topic:** Discovering topics in document collections
#
# ---
#
# ## Learning Objectives
# - Latent Dirichlet Allocation (LDA)
# - Non-negative Matrix Factorization
# - Topic visualization
# - Select optimal topics

# %%
# %pip install -q scikit-learn gensim pyLDAvis pandas numpy matplotlib

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# LDA with sklearn:
# 1. What is LDA (generative model)
# 2. Prepare document-term matrix
# 3. Fit LatentDirichletAllocation
# 4. Extract top words per topic
# 5. Assign documents to topics

# %%
# %%ai $MODEL
# Gensim LDA:
# 1. Create dictionary and corpus
# 2. Train LdaModel
# 3. Coherence score calculation
# 4. Find optimal number of topics
# 5. Update model with new documents

# %%
# %%ai $MODEL
# NMF topic modeling:
# 1. What is NMF
# 2. TF-IDF for NMF
# 3. Fit NMF model
# 4. Compare with LDA
# 5. When to use NMF vs LDA

# %%
# %%ai $MODEL
# Topic visualization:
# 1. pyLDAvis interactive visualization
# 2. Word clouds per topic
# 3. Topic distribution charts
# 4. Document-topic heatmap
# 5. Topic similarity

# %%
# %%ai $MODEL
# Topic model evaluation:
# 1. Perplexity metric
# 2. Coherence scores (C_v, UMass)
# 3. Human evaluation
# 4. Topic diversity
# 5. Interpretability assessment

# %% [markdown]
# ---
#
# ## Summary
#
# Covered topic modeling:
# - LDA with sklearn and gensim
# - NMF alternative
# - Visualization techniques
# - Evaluation metrics
# - Optimal topic selection
#
# ---
