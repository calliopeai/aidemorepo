# %% [markdown]
# # Text Classification
#
# **Category:** 13-NLP
# **Topic:** Classifying text into categories
#
# ---
#
# ## Learning Objectives
# - Text vectorization methods
# - Train classifiers
# - Multi-label classification
# - Handle imbalanced text data

# %%
# %pip install -q scikit-learn pandas numpy matplotlib

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Text vectorization:
# 1. Bag of Words (CountVectorizer)
# 2. TF-IDF (TfidfVectorizer)
# 3. N-grams features
# 4. Vocabulary size impact
# 5. Sparse matrix handling

# %%
# %%ai $MODEL
# Train text classifiers:
# 1. Load 20 newsgroups dataset
# 2. Preprocess and vectorize
# 3. Naive Bayes (Multinomial)
# 4. SVM classifier
# 5. Logistic Regression
# 6. Compare performance

# %%
# %%ai $MODEL
# Pipeline and hyperparameter tuning:
# 1. sklearn Pipeline for text
# 2. GridSearchCV for vectorizer params
# 3. Model hyperparameters
# 4. Cross-validation
# 5. Best model selection

# %%
# %%ai $MODEL
# Multi-label classification:
# 1. Multi-label vs multi-class
# 2. Binary relevance approach
# 3. Classifier chains
# 4. Evaluate multi-label metrics
# 5. Example: tag prediction

# %%
# %%ai $MODEL
# Handling imbalanced text:
# 1. Detect class imbalance
# 2. Class weight adjustment
# 3. Oversampling text data
# 4. Threshold tuning
# 5. Appropriate metrics (F1, AUC)

# %% [markdown]
# ---
#
# ## Summary
#
# Covered text classification:
# - Vectorization methods
# - Multiple classifiers
# - Pipelines and tuning
# - Multi-label scenarios
# - Imbalanced data
#
# ---
