# %% [markdown]
# # Bioinformatics Analysis
#
# **Category:** 10-Scientific
# **Topic:** Computational biology with AI
#
# ---
#
# ## Learning Objectives
# - Sequence analysis
# - Alignment algorithms
# - Phylogenetics
# - Protein structure

# %%
# %pip install -q biopython numpy matplotlib

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# DNA sequence analysis:
# 1. Parse FASTA files
# 2. GC content calculation
# 3. Codon usage
# 4. Open reading frames
# 5. Reverse complement

# %%
# %%ai $MODEL
# Sequence alignment:
# 1. Needleman-Wunsch (global)
# 2. Smith-Waterman (local)
# 3. Scoring matrices (BLOSUM)
# 4. Gap penalties
# 5. Multiple sequence alignment

# %%
# %%ai $MODEL
# BLAST and homology:
# 1. BLAST algorithm concept
# 2. E-values and significance
# 3. BioPython NCBI interface
# 4. Parsing BLAST results
# 5. Homolog identification

# %%
# %%ai $MODEL
# Phylogenetic analysis:
# 1. Distance matrices
# 2. UPGMA tree construction
# 3. Neighbor joining
# 4. Tree visualization
# 5. Bootstrap values

# %%
# %%ai $MODEL
# Protein analysis:
# 1. Amino acid properties
# 2. Hydropathy plots
# 3. Secondary structure prediction
# 4. Domain identification
# 5. PDB structure parsing

# %% [markdown]
# ---
#
# ## Summary
#
# Covered bioinformatics:
# - Sequence analysis
# - Alignment
# - BLAST
# - Phylogenetics
# - Protein analysis
#
# ---
