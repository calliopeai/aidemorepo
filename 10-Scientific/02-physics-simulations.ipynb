# %% [markdown]
# # Physics Simulations
#
# **Category:** 10-Scientific
# **Topic:** Computational physics with AI
#
# ---
#
# ## Learning Objectives
# - Particle dynamics
# - Wave equations
# - Monte Carlo methods
# - Visualization

# %%
# %pip install -q numpy scipy matplotlib

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# N-body simulation:
# 1. Gravitational force calculation
# 2. Velocity Verlet integration
# 3. Solar system simulation
# 4. Animation of orbits
# 5. Energy conservation check

# %%
# %%ai $MODEL
# Wave equation solver:
# 1. 1D wave equation
# 2. Finite difference method
# 3. Initial and boundary conditions
# 4. String vibration simulation
# 5. Animation of wave propagation

# %%
# %%ai $MODEL
# Heat diffusion:
# 1. Heat equation
# 2. 2D heat conduction
# 3. Explicit method
# 4. Steady state solution
# 5. Heatmap visualization

# %%
# %%ai $MODEL
# Monte Carlo integration:
# 1. Estimate pi using random points
# 2. Multi-dimensional integrals
# 3. Importance sampling
# 4. Error estimation
# 5. Convergence analysis

# %%
# %%ai $MODEL
# Pendulum dynamics:
# 1. Simple pendulum ODE
# 2. scipy.integrate.odeint
# 3. Double pendulum chaos
# 4. Phase space plots
# 5. Lyapunov exponents

# %% [markdown]
# ---
#
# ## Summary
#
# Covered physics simulations:
# - N-body gravity
# - Wave equations
# - Heat diffusion
# - Monte Carlo
# - Chaotic systems
#
# ---
