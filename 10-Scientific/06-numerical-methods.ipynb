# %% [markdown]
# # Numerical Methods
#
# **Category:** 10-Scientific
# **Topic:** Numerical computing with AI
#
# ---
#
# ## Learning Objectives
# - Root finding
# - Numerical integration
# - Linear algebra
# - Optimization

# %%
# %pip install -q numpy scipy matplotlib

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Root finding methods:
# 1. Bisection method
# 2. Newton-Raphson method
# 3. Secant method
# 4. scipy.optimize.root
# 5. Convergence comparison

# %%
# %%ai $MODEL
# Numerical integration:
# 1. Trapezoidal rule
# 2. Simpson's rule
# 3. Gaussian quadrature
# 4. scipy.integrate.quad
# 5. Multi-dimensional integrals

# %%
# %%ai $MODEL
# Linear algebra computations:
# 1. LU decomposition
# 2. Solving linear systems
# 3. Eigenvalue problems
# 4. SVD decomposition
# 5. Condition number

# %%
# %%ai $MODEL
# ODE solvers:
# 1. Euler method
# 2. Runge-Kutta methods
# 3. solve_ivp interface
# 4. Stiff equations
# 5. Event detection

# %%
# %%ai $MODEL
# Optimization algorithms:
# 1. Gradient descent
# 2. scipy.optimize.minimize
# 3. Constraints handling
# 4. Global optimization
# 5. Curve fitting

# %% [markdown]
# ---
#
# ## Summary
#
# Covered numerical methods:
# - Root finding
# - Integration
# - Linear algebra
# - ODEs
# - Optimization
#
# ---
