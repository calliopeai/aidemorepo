# %% [markdown]
# # Astronomy Data Analysis
#
# **Category:** 10-Scientific
# **Topic:** Astronomical computing with AI
#
# ---
#
# ## Learning Objectives
# - Astronomical coordinates
# - Catalog queries
# - Image processing
# - Light curve analysis

# %%
# %pip install -q astropy numpy matplotlib

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Astronomical coordinates:
# 1. Right Ascension/Declination
# 2. Galactic coordinates
# 3. Coordinate transformations
# 4. Astropy SkyCoord
# 5. Distance calculations

# %%
# %%ai $MODEL
# Catalog queries:
# 1. Vizier catalog access
# 2. SIMBAD database
# 3. Cone searches
# 4. Cross-matching catalogs
# 5. Object classification

# %%
# %%ai $MODEL
# FITS file handling:
# 1. Read FITS files
# 2. Image headers
# 3. WCS coordinates
# 4. Table extensions
# 5. Image visualization

# %%
# %%ai $MODEL
# Light curve analysis:
# 1. Time series data
# 2. Period detection
# 3. Phase folding
# 4. Variable star classification
# 5. Transit detection

# %%
# %%ai $MODEL
# Spectral analysis:
# 1. Wavelength calibration
# 2. Line identification
# 3. Redshift measurement
# 4. Spectral classification
# 5. Doppler shifts

# %% [markdown]
# ---
#
# ## Summary
#
# Covered astronomy:
# - Coordinates
# - Catalogs
# - FITS files
# - Light curves
# - Spectroscopy
#
# ---
