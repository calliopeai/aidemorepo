# %% [markdown]
# # Calliope AI Lab - Master Index
#
# **Welcome to the AI-Powered JupyterLab Demo Repository!**
#
# This collection showcases the full potential of AI-assisted data analysis, code generation, and database operations using Calliope AI and Jupyter AI.
#
# **61 Notebooks | 6 Pre-configured Databases | 15 Categories | Multiple AI Models**
#
# ---
#
# ## Quick Start
#
# 1. **New to Calliope?** Start with `00-Getting-Started/`
# 2. **Want to query databases?** Jump to `05-Database/datasources/`
# 3. **Need visualizations?** Check out `03-Visualization/`
#
# ---

# %% [markdown]
# ## Repository Structure
#
# ```
# Calliope-AI-Lab-Demo/
# ├── 00-Getting-Started/      # Setup, configuration, quickstart (4 notebooks)
# ├── 01-Code-Generation/      # AI code assistant, refactoring (1 notebook)
# ├── 02-Data-Exploration/     # EDA, profiling, data cleaning (6 notebooks)
# ├── 03-Visualization/        # Matplotlib, Seaborn, Plotly (8 notebooks)
# ├── 04-RAG-Documents/        # PDF Q&A, semantic search (2 notebooks)
# ├── 05-Database/             # SQL generation, datasources (10 notebooks)
# │   └── datasources/         # Sakila, Chinook, Employees, etc.
# ├── 06-AI-ML/                # Classification, forecasting (2 notebooks)
# ├── 07-DevOps/               # Infrastructure, monitoring (2 notebooks)
# ├── 08-InfoSec/              # Security analysis, pentesting (2 notebooks)
# ├── 09-FinOps-Cloud/         # AWS cost analysis (1 notebook)
# ├── 10-Scientific/           # Signal processing, geospatial (5 notebooks)
# ├── 11-Financial/            # Portfolio, options, risk (5 notebooks)
# ├── 12-Time-Series/          # Forecasting, anomaly detection (2 notebooks)
# ├── 13-NLP/                  # Text generation, sentiment (2 notebooks)
# ├── 14-Advanced/             # Complex examples, patterns (4 notebooks)
# └── 15-Reference/            # Documentation, API guides (3 notebooks)
# ```
#
# ---

# %% [markdown]
# ## Category Guide
#
# ### 00 - Getting Started (4 notebooks)
# | Notebook | Description |
# |----------|-------------|
# | `00-model-config.ipynb` | **START HERE** - Model aliases configuration |
# | `00-Setup-Calliope.ipynb` | Environment setup and API configuration |
# | `Calliope-GettingStarted.ipynb` | First steps with Calliope |
# | `Calliope_Quick_Start.ipynb` | Quick reference guide |
#
# ### 01 - Code Generation (1 notebook)
# | Notebook | Description |
# |----------|-------------|
# | `01-ai-code-assistant.ipynb` | Generate, refactor, debug, and document code with AI |
#
# ### 02 - Data Exploration (6 notebooks)
# | Notebook | Description |
# |----------|-------------|
# | `01-eda-profiling.ipynb` | Automated EDA with AI insights |
# | `01_MVA_Vehicle_Sales_Advanced.ipynb` | Advanced vehicle sales analysis |
# | `03_Crime_Data_Spatiotemporal.ipynb` | Crime pattern analysis |
# | `04_Baby_Names_Trend_Analysis.ipynb` | Name trend analysis |
# | `12_Motor_Fuel_Energy_Analytics.ipynb` | Energy analytics |
# | `CSV_Column_Normalizer.ipynb` | Data cleaning and normalization |
#
# ### 03 - Visualization (8 notebooks)
# | Notebook | Description |
# |----------|-------------|
# | `AI-Visualization-Showcase.ipynb` | Featured AI visualization examples |
# | `Calliope-Visualizations.ipynb` | Automatic chart generation |
# | `MathplotlibExampleAI.ipynb` | Matplotlib examples |
# | `SeabornVizDemo.ipynb` | Statistical visualizations |
# | `SeabornAI.ipynb` | 3D visualizations |
# | `Combined Plotly.ipynb` | Interactive Plotly charts |
# | `GraphAI.ipynb` | Graph visualizations |
# | `Lorenz Attractor Demo.ipynb` | 3D scientific visualization |
#
# ### 04 - RAG & Documents (2 notebooks)
# | Notebook | Description |
# |----------|-------------|
# | `01-pdf-qa.ipynb` | PDF question answering with RAG |
# | `Calliope-RAGTraining.ipynb` | Train Calliope with business logic |
#
# ### 05 - Database (10 notebooks)
# | Notebook | Description |
# |----------|-------------|
# | `Calliope-AdvancedQueries.ipynb` | Complex SQL with window functions, CTEs |
# | `Calliope-DirectSQL.ipynb` | Direct SQL control and debugging |
# | `MySQL-Features-Showcase.ipynb` | MySQL-specific features |
# | `PostgreSQL-Features-Showcase.ipynb` | PostgreSQL-specific features |
#
# #### Pre-configured Databases (05-Database/datasources/)
# | Database | Type | Description |
# |----------|------|-------------|
# | `Datasource-Sakila.ipynb` | MySQL | DVD rental store - retail analytics |
# | `Datasource-Chinook.ipynb` | PostgreSQL | Digital music store - e-commerce |
# | `Datasource-Employees.ipynb` | MySQL | HR database - people analytics |
# | `Datasource-Northwind.ipynb` | PostgreSQL | Business operations - supply chain |
# | `Datasource-World.ipynb` | MySQL | Geographic data - demographics |
# | `Datasource-AirportDB.ipynb` | MySQL | Airport operations - transportation |
#
# ### 06 - AI/ML (2 notebooks)
# | Notebook | Description |
# |----------|-------------|
# | `01-classification-diabetes.ipynb` | ML classification with AI guidance |
# | `05_Diabetes_ML_Classification.ipynb` | Advanced ML with SHAP explanations |
#
# ### 07 - DevOps (2 notebooks)
# | Notebook | Description |
# |----------|-------------|
# | `Dual Webservice with Graphing.ipynb` | API integration with visualization |
# | `09_Supply_Chain_Carbon_Network.ipynb` | Supply chain network analysis |
#
# ### 08 - InfoSec (2 notebooks)
# | Notebook | Description |
# |----------|-------------|
# | `01-security-analysis.ipynb` | Security log analysis and threat detection |
# | `backcountry_pentest.ipynb` | Penetration testing examples |
#
# ### 09 - FinOps/Cloud (1 notebook)
# | Notebook | Description |
# |----------|-------------|
# | `01-aws-cost-analysis.ipynb` | AWS cost analysis and optimization |
#
# ### 10 - Scientific (5 notebooks)
# | Notebook | Description |
# |----------|-------------|
# | `01-signal-processing.ipynb` | FFT, filtering, spectral analysis |
# | `02_Electric_Vehicles_Geospatial.ipynb` | EV spatial analysis |
# | `08_Health_Nutrition_Geospatial.ipynb` | Health geography analysis |
# | `10_EPA_SmartLocation_Walkability.ipynb` | Urban walkability analysis |
# | `11_Chronic_Disease_Epidemiology.ipynb` | Epidemiological analysis |
#
# ### 11 - Financial (5 notebooks)
# | Notebook | Description |
# |----------|-------------|
# | `01-portfolio-optimization.ipynb` | Modern Portfolio Theory, Sharpe ratio |
# | `02-options-pricing.ipynb` | Black-Scholes, Greeks |
# | `03-risk-analysis.ipynb` | VaR, Monte Carlo simulation |
# | `04-technical-analysis.ipynb` | Moving averages, RSI, MACD |
# | `07_Salary_Equity_Analysis.ipynb` | Compensation analysis |
#
# ### 12 - Time Series (2 notebooks)
# | Notebook | Description |
# |----------|-------------|
# | `01-forecasting-sales.ipynb` | Sales forecasting with ARIMA, Prophet |
# | `06_Warehouse_Retail_Forecasting.ipynb` | Retail demand forecasting |
#
# ### 13 - NLP (2 notebooks)
# | Notebook | Description |
# |----------|-------------|
# | `TextGeneration.ipynb` | AI text generation |
# | `Limmerick.ipynb` | Creative writing with AI |
#
# ### 14 - Advanced (4 notebooks)
# | Notebook | Description |
# |----------|-------------|
# | `00_INDEX_Notebook_Guide.ipynb` | Advanced notebook patterns |
# | `00_Library_Discovery.ipynb` | Library exploration |
# | `Calliope_Advanced_Patterns.ipynb` | Complex Calliope workflows |
# | `Poetry and Entanglement.ipynb` | Experimental AI poetry |
#
# ### 15 - Reference (3 notebooks)
# | Notebook | Description |
# |----------|-------------|
# | `Calliope-JupyterAI-Integration.ipynb` | Multi-model workflows |
# | `Test-Calliope-Magic.ipynb` | Testing Calliope commands |
# | `Integrating GPT Prompts...` | Complete GPT integration guide |
#
# ---

# %% [markdown]
# ## Learning Paths
#
# ### Path 1: Data Analyst
# 1. `00-Getting-Started/00-model-config.ipynb`
# 2. `05-Database/datasources/Datasource-Sakila.ipynb`
# 3. `02-Data-Exploration/01-eda-profiling.ipynb`
# 4. `03-Visualization/Calliope-Visualizations.ipynb`
#
# ### Path 2: Data Scientist
# 1. `00-Getting-Started/00-model-config.ipynb`
# 2. `06-AI-ML/01-classification-diabetes.ipynb`
# 3. `12-Time-Series/01-forecasting-sales.ipynb`
# 4. `10-Scientific/01-signal-processing.ipynb`
#
# ### Path 3: Developer
# 1. `00-Getting-Started/00-model-config.ipynb`
# 2. `01-Code-Generation/01-ai-code-assistant.ipynb`
# 3. `05-Database/Calliope-DirectSQL.ipynb`
# 4. `04-RAG-Documents/01-pdf-qa.ipynb`
#
# ### Path 4: Finance/Quant
# 1. `00-Getting-Started/00-model-config.ipynb`
# 2. `11-Financial/01-portfolio-optimization.ipynb`
# 3. `11-Financial/02-options-pricing.ipynb`
# 4. `11-Financial/03-risk-analysis.ipynb`
#
# ### Path 5: Cloud/DevOps
# 1. `00-Getting-Started/00-model-config.ipynb`
# 2. `09-FinOps-Cloud/01-aws-cost-analysis.ipynb`
# 3. `08-InfoSec/01-security-analysis.ipynb`
# 4. `07-DevOps/09_Supply_Chain_Carbon_Network.ipynb`
#
# ---

# %% [markdown]
# ## Model Configuration
#
# Each notebook uses model aliases for easy updates:
#
# ```python
# # Current recommended models (December 2025)
# CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
# GPT = "openai-chat:gpt-5"
# GEMINI = "gemini:gemini-2.5-flash"
#
# # Usage with Calliope
# %calliope -d sakila --sql-model $CLAUDE "Show top customers"
#
# # Usage with Jupyter AI
# %%ai $CLAUDE
# Explain SQL window functions
# ```
#
# **See `00-Getting-Started/00-model-config.ipynb` for full configuration.**
#
# ---

# %% [markdown]
# ## Available Data
#
# ### Pre-configured Databases
# | Database | Type | Tables | Use Case |
# |----------|------|--------|----------|
# | Sakila | MySQL | film, customer, rental, payment | Retail, inventory |
# | Chinook | PostgreSQL | artist, album, track, invoice | E-commerce, music |
# | Employees | MySQL | employees, salaries, departments | HR, compensation |
# | Northwind | PostgreSQL | products, orders, customers | Supply chain, B2B |
# | World | MySQL | country, city, countrylanguage | Geography, demographics |
# | AirportDB | MySQL | flights, airports, airlines | Transportation, logistics |
#
# ### CSV Datasets (~/lab/data/CSVs/)
# | Dataset | Size | Use Case |
# |---------|------|----------|
# | Crime_Data | 244MB | Spatiotemporal analysis |
# | EPA_SmartLocation | 193MB | Urban analytics |
# | Electric_Vehicle | 57MB | Transportation, geospatial |
# | Chronic_Disease | 85MB | Healthcare analytics |
# | Warehouse_Sales | 27MB | Time series, forecasting |
# | Baby_Names | 2.7MB | Trend analysis |
# | Diabetes | 16KB | ML classification |
#
# ### PDF Documents (~/lab/data/PDFs/)
# - Google Borg, Autopilot papers
# - O'Reilly Observability Engineering
# - SRE Incident Metrics
# - Control Systems Theory
# - ML Exercises
#
# ---

# %% [markdown]
# ## Quick Reference
#
# ### Calliope Commands
# ```python
# %calliope                         # Show help
# %calliope list                    # List datasources
# %calliope list-models             # List AI models
# %calliope -d sakila "query"       # Natural language query
# %calliope -d sakila schema        # Show database schema
# %calliope -d sakila --sql-model $MODEL "query"  # Specify model
# %calliope -d sakila --to-ai $MODEL "query"      # Get AI analysis
# ```
#
# ### Jupyter AI Magic
# ```python
# %%ai $MODEL                       # General AI query
# %%ai $MODEL -f code               # Generate code
# ```
#
# ---

# %%
# Verify Calliope is available
# %calliope

# %%
# List available datasources
# %calliope list

# %%
# List available models
# %calliope list-models

# %% [markdown]
# ---
#
# ## Getting Started Checklist
#
# **Quick Start (5 minutes)**
# - [ ] Open `05-Database/datasources/Datasource-Sakila.ipynb`
# - [ ] Run the first query cell
# - [ ] You're analyzing data with AI!
#
# **Full Experience (30 minutes)**
# - [ ] Complete `00-Getting-Started/00-model-config.ipynb`
# - [ ] Try 2-3 datasource notebooks
# - [ ] Explore `03-Visualization/`
# - [ ] Check out `11-Financial/` or `10-Scientific/`
#
# ---
#
# **Happy exploring!**
