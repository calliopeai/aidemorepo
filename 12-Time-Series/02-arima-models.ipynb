# %% [markdown]
# # ARIMA Time Series Models
#
# **Category:** 12-Time-Series
# **Topic:** ARIMA and SARIMA modeling
#
# ---
#
# ## Learning Objectives
# - Understand AR, I, MA components
# - Check stationarity
# - Select model orders (p, d, q)
# - Implement SARIMA for seasonality

# %%
# %pip install -q statsmodels pandas numpy matplotlib pmdarima

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Explain ARIMA components:
# 1. AutoRegressive (AR) term
# 2. Integrated (I) differencing
# 3. Moving Average (MA) term
# 4. How they combine in ARIMA(p,d,q)
# 5. Intuition with simple examples

# %%
# %%ai $MODEL
# Stationarity testing:
# 1. Visual inspection of time series
# 2. Augmented Dickey-Fuller test
# 3. KPSS test
# 4. Differencing to achieve stationarity
# 5. Determine order of differencing (d)

# %%
# %%ai $MODEL
# ARIMA order selection:
# 1. ACF plot for MA order (q)
# 2. PACF plot for AR order (p)
# 3. Grid search with AIC/BIC
# 4. Use auto_arima from pmdarima
# 5. Residual diagnostics

# %%
# %%ai $MODEL
# SARIMA for seasonal data:
# 1. Generate seasonal time series
# 2. Identify seasonal pattern
# 3. SARIMA(p,d,q)(P,D,Q,s) notation
# 4. Fit model with statsmodels
# 5. Forecast with confidence intervals

# %%
# %%ai $MODEL
# Complete ARIMA pipeline:
# 1. Load real dataset (airline passengers)
# 2. Train/test split (time-based)
# 3. Find optimal parameters
# 4. Train SARIMA model
# 5. Forecast and evaluate (RMSE, MAPE)

# %% [markdown]
# ---
#
# ## Summary
#
# Covered ARIMA modeling:
# - AR, I, MA components
# - Stationarity testing
# - Order selection methods
# - SARIMA for seasonality
# - Complete forecasting pipeline
#
# ---
