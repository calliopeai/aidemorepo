# %% [markdown]
# # Time Series Anomaly Detection
#
# **Category:** 12-Time-Series
# **Topic:** Detecting anomalies in time series
#
# ---
#
# ## Learning Objectives
# - Statistical anomaly detection
# - ML-based approaches
# - Streaming anomaly detection
# - Evaluate detection quality

# %%
# %pip install -q pandas numpy matplotlib scikit-learn pyod

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Statistical anomaly detection:
# 1. Z-score method
# 2. IQR (Interquartile Range)
# 3. Moving average deviation
# 4. Seasonal hybrid ESD
# 5. Visualize detected anomalies

# %%
# %%ai $MODEL
# ML-based anomaly detection:
# 1. Isolation Forest for time series
# 2. One-class SVM
# 3. Local Outlier Factor
# 4. Feature engineering for TS
# 5. Compare methods on same data

# %%
# %%ai $MODEL
# Autoencoder anomaly detection:
# 1. Build autoencoder model
# 2. Train on normal data
# 3. Reconstruction error as anomaly score
# 4. Set threshold
# 5. LSTM autoencoder for sequences

# %%
# %%ai $MODEL
# Streaming anomaly detection:
# 1. ARIMA residuals approach
# 2. Rolling statistics
# 3. Online learning methods
# 4. Handle concept drift
# 5. Real-time alerting logic

# %%
# %%ai $MODEL
# Evaluation and tuning:
# 1. Create labeled anomaly dataset
# 2. Precision, Recall, F1
# 3. ROC curve for threshold selection
# 4. Time-aware evaluation
# 5. Production monitoring setup

# %% [markdown]
# ---
#
# ## Summary
#
# Covered anomaly detection:
# - Statistical methods
# - ML algorithms
# - Autoencoder approach
# - Streaming detection
# - Evaluation metrics
#
# ---
