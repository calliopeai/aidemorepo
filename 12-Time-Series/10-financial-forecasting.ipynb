# %% [markdown]
# # Financial Time Series Forecasting
#
# **Category:** 12-Time-Series
# **Topic:** Forecasting financial data
#
# ---
#
# ## Learning Objectives
# - Stock price forecasting
# - Volatility modeling (GARCH)
# - Return analysis
# - Risk metrics

# %%
# %pip install -q yfinance arch pandas numpy matplotlib

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Financial data characteristics:
# 1. Non-stationarity of prices
# 2. Returns vs prices (log returns)
# 3. Fat tails and volatility clustering
# 4. Mean reversion vs random walk
# 5. Why prices are hard to predict

# %%
# %%ai $MODEL
# Volatility modeling with GARCH:
# 1. What is ARCH/GARCH
# 2. Why volatility clusters
# 3. Fit GARCH(1,1) model
# 4. Forecast volatility
# 5. EGARCH for asymmetric effects

# %%
# %%ai $MODEL
# Value at Risk (VaR):
# 1. VaR concept and interpretation
# 2. Historical simulation method
# 3. Parametric VaR (normal)
# 4. Monte Carlo simulation
# 5. Backtesting VaR models

# %%
# %%ai $MODEL
# Technical analysis features:
# 1. Moving averages (SMA, EMA)
# 2. Bollinger Bands
# 3. RSI (Relative Strength Index)
# 4. MACD indicator
# 5. Use as ML features

# %%
# %%ai $MODEL
# ML for financial prediction:
# 1. Predict direction (up/down)
# 2. Feature engineering from price data
# 3. Time series cross-validation
# 4. Avoid look-ahead bias
# 5. Realistic backtesting setup

# %% [markdown]
# ---
#
# ## Summary
#
# Covered financial forecasting:
# - Financial data properties
# - GARCH volatility models
# - Value at Risk
# - Technical indicators
# - ML for finance
#
# ---
