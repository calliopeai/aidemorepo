# %% [markdown]
# # Exponential Smoothing Methods
#
# **Category:** 12-Time-Series
# **Topic:** Exponential smoothing and Holt-Winters
#
# ---
#
# ## Learning Objectives
# - Simple exponential smoothing
# - Holt's linear trend method
# - Holt-Winters seasonal method
# - Compare with ARIMA

# %%
# %pip install -q statsmodels pandas numpy matplotlib

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Simple Exponential Smoothing (SES):
# 1. Explain the smoothing concept
# 2. Alpha parameter meaning
# 3. Implement from scratch
# 4. Use statsmodels SimpleExpSmoothing
# 5. Tune alpha with cross-validation

# %%
# %%ai $MODEL
# Holt's Linear Trend Method:
# 1. Add trend component
# 2. Level and trend equations
# 3. Alpha and beta parameters
# 4. Damped trend variation
# 5. Compare damped vs non-damped

# %%
# %%ai $MODEL
# Holt-Winters Seasonal Method:
# 1. Add seasonal component (gamma)
# 2. Additive vs multiplicative seasonality
# 3. When to use each type
# 4. Implement with ExponentialSmoothing
# 5. Seasonal period selection

# %%
# %%ai $MODEL
# ETS models (Error, Trend, Seasonal):
# 1. ETS taxonomy (AAA, MAM, etc.)
# 2. Automatic model selection
# 3. AIC/BIC for model comparison
# 4. State space representation
# 5. Prediction intervals

# %%
# %%ai $MODEL
# Comparison: ETS vs ARIMA:
# 1. Same dataset (monthly sales)
# 2. Fit best ETS model
# 3. Fit best ARIMA model
# 4. Cross-validation comparison
# 5. When to prefer each method

# %% [markdown]
# ---
#
# ## Summary
#
# Covered exponential smoothing:
# - Simple exponential smoothing
# - Holt's linear trend
# - Holt-Winters seasonal
# - ETS model framework
# - Comparison with ARIMA
#
# ---
