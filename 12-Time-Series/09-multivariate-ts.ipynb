# %% [markdown]
# # Multivariate Time Series
#
# **Category:** 12-Time-Series
# **Topic:** Analyzing multiple related series
#
# ---
#
# ## Learning Objectives
# - VAR models
# - Granger causality
# - Cointegration analysis
# - Cross-correlation

# %%
# %pip install -q statsmodels pandas numpy matplotlib

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Vector AutoRegression (VAR):
# 1. What is VAR model
# 2. When to use VAR
# 3. Check stationarity for each series
# 4. Select optimal lag order
# 5. Fit VAR model with statsmodels

# %%
# %%ai $MODEL
# Granger Causality:
# 1. What Granger causality means
# 2. Not actual causality (predictive)
# 3. Perform Granger test
# 4. Interpret p-values
# 5. Bidirectional causality check

# %%
# %%ai $MODEL
# Impulse Response Analysis:
# 1. What is impulse response
# 2. Shock in one variable
# 3. Effect on other variables
# 4. Plot impulse response functions
# 5. Forecast error variance decomposition

# %%
# %%ai $MODEL
# Cointegration:
# 1. Non-stationary but cointegrated
# 2. Engle-Granger two-step
# 3. Johansen test
# 4. VECM (Vector Error Correction)
# 5. Applications (pairs trading)

# %%
# %%ai $MODEL
# Cross-correlation analysis:
# 1. Compute cross-correlation
# 2. Lead-lag relationships
# 3. Identify optimal lag
# 4. Visualize CCF plot
# 5. Use for feature engineering

# %% [markdown]
# ---
#
# ## Summary
#
# Covered multivariate TS:
# - VAR modeling
# - Granger causality
# - Impulse response
# - Cointegration
# - Cross-correlation
#
# ---
