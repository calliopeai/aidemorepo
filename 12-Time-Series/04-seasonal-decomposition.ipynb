# %% [markdown]
# # Seasonal Decomposition
#
# **Category:** 12-Time-Series
# **Topic:** Decomposing time series components
#
# ---
#
# ## Learning Objectives
# - Decompose into trend, seasonal, residual
# - STL decomposition
# - Identify patterns visually
# - Use decomposition for forecasting

# %%
# %pip install -q statsmodels pandas numpy matplotlib

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Classical decomposition:
# 1. Time series components (T, S, R)
# 2. Additive decomposition (Y = T + S + R)
# 3. Multiplicative decomposition (Y = T × S × R)
# 4. Use seasonal_decompose from statsmodels
# 5. Visualize all components

# %%
# %%ai $MODEL
# STL decomposition:
# 1. What STL stands for (Seasonal-Trend-LOESS)
# 2. Advantages over classical
# 3. Robust to outliers
# 4. Configurable seasonality
# 5. Compare with classical decomposition

# %%
# %%ai $MODEL
# Multiple seasonalities:
# 1. MSTL for multiple seasonal periods
# 2. Example: daily with weekly and yearly
# 3. Fourier terms for flexibility
# 4. Handling complex patterns
# 5. Visualization of multiple cycles

# %%
# %%ai $MODEL
# Trend analysis:
# 1. Moving average for trend extraction
# 2. HP filter (Hodrick-Prescott)
# 3. Baxter-King filter
# 4. Compare trend methods
# 5. Cycle identification

# %%
# %%ai $MODEL
# Decomposition-based forecasting:
# 1. Forecast each component separately
# 2. Recombine for final forecast
# 3. Seasonal naive method
# 4. Trend extrapolation methods
# 5. Compare with direct forecasting

# %% [markdown]
# ---
#
# ## Summary
#
# Covered decomposition:
# - Classical additive/multiplicative
# - STL decomposition
# - Multiple seasonalities
# - Trend filtering
# - Decomposition for forecasting
#
# ---
