# %% [markdown]
# # Prophet Forecasting
#
# **Category:** 12-Time-Series
# **Topic:** Facebook Prophet for forecasting
#
# ---
#
# ## Learning Objectives
# - Set up and use Prophet
# - Handle holidays and events
# - Add custom seasonalities
# - Tune hyperparameters

# %%
# %pip install -q prophet pandas numpy matplotlib

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Prophet basics:
# 1. Prophet model components
# 2. Data format requirements (ds, y)
# 3. Fit simple model
# 4. Make future predictions
# 5. Plot forecast with components

# %%
# %%ai $MODEL
# Holidays and special events:
# 1. Create holidays dataframe
# 2. Add country holidays
# 3. Custom events (promotions, etc.)
# 4. Event windows (before/after)
# 5. Visualize holiday effects

# %%
# %%ai $MODEL
# Custom seasonalities:
# 1. Add weekly seasonality
# 2. Monthly seasonality
# 3. Quarterly patterns
# 4. Conditional seasonality
# 5. Fourier order tuning

# %%
# %%ai $MODEL
# Adding regressors:
# 1. External variables impact
# 2. Add regressor to model
# 3. Future regressor values
# 4. Multiple regressors
# 5. Compare with/without regressors

# %%
# %%ai $MODEL
# Prophet tuning and evaluation:
# 1. Changepoint configuration
# 2. Seasonality prior scale
# 3. Cross-validation in Prophet
# 4. Performance metrics (MAPE, etc.)
# 5. Hyperparameter grid search

# %% [markdown]
# ---
#
# ## Summary
#
# Covered Prophet:
# - Basic forecasting
# - Holidays and events
# - Custom seasonalities
# - External regressors
# - Model tuning
#
# ---
