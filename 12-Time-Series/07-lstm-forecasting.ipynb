# %% [markdown]
# # LSTM Time Series Forecasting
#
# **Category:** 12-Time-Series
# **Topic:** Deep learning for time series
#
# ---
#
# ## Learning Objectives
# - Understand LSTM architecture
# - Prepare data for sequences
# - Build LSTM models
# - Multi-step forecasting

# %%
# %pip install -q tensorflow pandas numpy matplotlib scikit-learn

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# LSTM architecture for time series:
# 1. Why RNNs fail (vanishing gradients)
# 2. LSTM cell components (forget, input, output gates)
# 3. How LSTMs remember long sequences
# 4. Bidirectional LSTM
# 5. Stacked LSTM layers

# %%
# %%ai $MODEL
# Data preparation for LSTM:
# 1. Create sliding window sequences
# 2. Scale data (MinMax or Standard)
# 3. Reshape to 3D (samples, timesteps, features)
# 4. Train/validation/test split
# 5. Handle inverse scaling for predictions

# %%
# %%ai $MODEL
# Build univariate LSTM model:
# 1. Single input sequence
# 2. Model architecture (layers, units)
# 3. Compile and train
# 4. Plot training curves
# 5. Make predictions and evaluate

# %%
# %%ai $MODEL
# Multivariate LSTM:
# 1. Multiple input features
# 2. Prepare multivariate sequences
# 3. Model with multiple inputs
# 4. Encode-decoder architecture
# 5. Compare with univariate

# %%
# %%ai $MODEL
# Multi-step forecasting:
# 1. Direct multi-step output
# 2. Recursive prediction
# 3. Sequence-to-sequence model
# 4. Attention mechanism
# 5. Compare approaches on same data

# %% [markdown]
# ---
#
# ## Summary
#
# Covered LSTM forecasting:
# - LSTM architecture
# - Sequence data preparation
# - Univariate models
# - Multivariate models
# - Multi-step prediction
#
# ---
