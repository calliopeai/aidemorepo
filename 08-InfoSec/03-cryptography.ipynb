# %% [markdown]
# # Cryptography Fundamentals
#
# **Category:** 08-InfoSec
# **Topic:** Encryption and cryptographic concepts
#
# ---
#
# ## Learning Objectives
# - Symmetric vs asymmetric encryption
# - Hashing algorithms
# - Digital signatures
# - TLS/SSL basics

# %%
# %pip install -q cryptography

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Symmetric encryption:
# 1. AES algorithm
# 2. Block cipher modes (CBC, GCM)
# 3. Key management
# 4. Python cryptography library
# 5. Encrypt/decrypt example

# %%
# %%ai $MODEL
# Asymmetric encryption:
# 1. RSA algorithm
# 2. Public/private key pairs
# 3. Key generation
# 4. Encryption with public key
# 5. When to use asymmetric

# %%
# %%ai $MODEL
# Hashing:
# 1. SHA-256 and SHA-3
# 2. Password hashing (bcrypt, Argon2)
# 3. HMAC
# 4. Hash verification
# 5. Rainbow table protection

# %%
# %%ai $MODEL
# Digital signatures:
# 1. How signatures work
# 2. Sign with private key
# 3. Verify with public key
# 4. X.509 certificates
# 5. Code signing

# %%
# %%ai $MODEL
# TLS/SSL:
# 1. TLS handshake
# 2. Certificate chain
# 3. Certificate authorities
# 4. Let's Encrypt
# 5. Common misconfigurations

# %% [markdown]
# ---
#
# ## Summary
#
# Covered cryptography:
# - Symmetric encryption
# - Asymmetric encryption
# - Hashing
# - Digital signatures
# - TLS/SSL
#
# ---
