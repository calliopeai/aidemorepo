# %% [markdown]
# # Web Application Security
#
# **Category:** 08-InfoSec
# **Topic:** OWASP Top 10 and web security
#
# ---
#
# ## Learning Objectives
# - OWASP Top 10 vulnerabilities
# - XSS prevention
# - SQL injection defense
# - CSRF protection

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# OWASP Top 10 2021:
# 1. Broken Access Control
# 2. Cryptographic Failures
# 3. Injection
# 4. Insecure Design
# 5. Security Misconfiguration

# %%
# %%ai $MODEL
# XSS (Cross-Site Scripting):
# 1. Types: Reflected, Stored, DOM
# 2. Attack examples
# 3. Output encoding
# 4. Content Security Policy
# 5. Framework protections

# %%
# %%ai $MODEL
# SQL Injection:
# 1. Attack mechanisms
# 2. Parameterized queries
# 3. ORM usage
# 4. Input validation
# 5. Least privilege database

# %%
# %%ai $MODEL
# CSRF and session security:
# 1. CSRF attack flow
# 2. Anti-CSRF tokens
# 3. SameSite cookies
# 4. Session fixation
# 5. Secure cookie flags

# %%
# %%ai $MODEL
# Security headers:
# 1. Content-Security-Policy
# 2. X-Frame-Options
# 3. X-Content-Type-Options
# 4. Strict-Transport-Security
# 5. Referrer-Policy

# %% [markdown]
# ---
#
# ## Summary
#
# Covered web security:
# - OWASP Top 10
# - XSS prevention
# - SQL injection
# - CSRF protection
# - Security headers
#
# ---
