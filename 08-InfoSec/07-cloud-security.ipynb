# %% [markdown]
# # Cloud Security
#
# **Category:** 08-InfoSec
# **Topic:** Securing cloud infrastructure
#
# ---
#
# ## Learning Objectives
# - Shared responsibility model
# - IAM best practices
# - Cloud security services
# - Compliance frameworks

# %%
# =============================================================================
# AUTO-INSTALL DEPENDENCIES
# Run this cell to scan the notebook and install required packages
# =============================================================================
# %%calliope ask claude --format code
Scan this notebook for all Python imports and library dependencies.
Generate a shell script that:
1. Checks if each required package is installed
2. Installs any missing packages using pip
Output only the executable shell commands, no explanations.

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Shared responsibility model:
# 1. Provider responsibilities
# 2. Customer responsibilities
# 3. IaaS vs PaaS vs SaaS
# 4. Security controls ownership
# 5. Common misunderstandings

# %%
# %%ai $MODEL
# Cloud IAM:
# 1. Least privilege principle
# 2. Role-based access
# 3. Service accounts
# 4. Cross-account access
# 5. IAM policies review

# %%
# %%ai $MODEL
# Data protection in cloud:
# 1. Encryption at rest
# 2. Encryption in transit
# 3. Key management (KMS)
# 4. Data classification
# 5. Data residency

# %%
# %%ai $MODEL
# Cloud security services:
# 1. AWS GuardDuty/SecurityHub
# 2. Azure Defender
# 3. Cloud SIEM
# 4. CASB solutions
# 5. CSPM tools

# %%
# %%ai $MODEL
# Compliance:
# 1. SOC 2
# 2. PCI-DSS
# 3. HIPAA
# 4. GDPR
# 5. Compliance automation

# %% [markdown]
# ---
#
# ## Summary
#
# Covered cloud security:
# - Shared responsibility
# - IAM practices
# - Data protection
# - Security services
# - Compliance
#
# ---
