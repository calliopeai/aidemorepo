# %% [markdown]
# # Data Transfer Cost Optimization
#
# **Category:** 09-FinOps-Cloud
# **Topic:** Network and egress cost management
#
# ---
#
# ## Learning Objectives
# - Data transfer pricing
# - Egress optimization
# - CDN strategies
# - Cross-region costs

# %%
# =============================================================================
# AUTO-INSTALL DEPENDENCIES
# Run this cell to scan the notebook and install required packages
# =============================================================================
# %%calliope ask claude --format code
Scan this notebook for all Python imports and library dependencies.
Generate a shell script that:
1. Checks if each required package is installed
2. Installs any missing packages using pip
Output only the executable shell commands, no explanations.

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Data transfer pricing:
# 1. Ingress (usually free)
# 2. Egress to internet
# 3. Inter-region transfer
# 4. Inter-AZ transfer
# 5. VPC peering costs

# %%
# %%ai $MODEL
# Egress reduction:
# 1. Data compression
# 2. Caching strategies
# 3. Edge computing
# 4. Regional data locality
# 5. API pagination

# %%
# %%ai $MODEL
# CDN cost optimization:
# 1. CloudFront pricing
# 2. Price class selection
# 3. Cache hit ratio
# 4. Origin shield
# 5. CDN vs direct transfer

# %%
# %%ai $MODEL
# Architecture decisions:
# 1. Same-AZ deployments
# 2. VPC endpoints
# 3. NAT Gateway alternatives
# 4. Direct Connect
# 5. Transit Gateway

# %%
# %%ai $MODEL
# Monitoring data transfer:
# 1. VPC Flow Logs
# 2. Cost allocation
# 3. Top talkers analysis
# 4. Unexpected egress alerts
# 5. Cost projections

# %% [markdown]
# ---
#
# ## Summary
#
# Covered data transfer:
# - Pricing model
# - Egress reduction
# - CDN optimization
# - Architecture
# - Monitoring
#
# ---
