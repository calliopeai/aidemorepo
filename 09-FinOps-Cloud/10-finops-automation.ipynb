# %% [markdown]
# # FinOps Automation
#
# **Category:** 09-FinOps-Cloud
# **Topic:** Automating cost optimization
#
# ---
#
# ## Learning Objectives
# - Automated scheduling
# - Policy-based actions
# - Cost governance
# - IaC for cost control

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Resource scheduling:
# 1. Start/stop schedules
# 2. AWS Instance Scheduler
# 3. Dev/test environments
# 4. Lambda for automation
# 5. Time zone handling

# %%
# %%ai $MODEL
# Policy-based automation:
# 1. AWS Service Control Policies
# 2. Azure Policy
# 3. Deny expensive instances
# 4. Require tagging
# 5. Region restrictions

# %%
# %%ai $MODEL
# Cleanup automation:
# 1. Unused resource detection
# 2. Automated cleanup Lambda
# 3. Age-based deletion
# 4. Approval workflows
# 5. Audit logging

# %%
# %%ai $MODEL
# Terraform cost controls:
# 1. Infracost pre-commit
# 2. Cost estimates in PRs
# 3. Budget guards
# 4. Sentinel policies
# 5. Module best practices

# %%
# %%ai $MODEL
# FinOps workflows:
# 1. Weekly optimization reports
# 2. Slack/Teams alerts
# 3. Automated recommendations
# 4. Self-service portals
# 5. Cost approval workflows

# %% [markdown]
# ---
#
# ## Summary
#
# Covered automation:
# - Resource scheduling
# - Policy automation
# - Cleanup
# - IaC integration
# - Workflows
#
# ---
