# %% [markdown]
# # Reserved Instances & Savings Plans
#
# **Category:** 09-FinOps-Cloud
# **Topic:** Commitment-based discounts
#
# ---
#
# ## Learning Objectives
# - Reserved instance types
# - Savings Plans options
# - Coverage analysis
# - Purchase recommendations

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Reserved Instances:
# 1. Standard vs Convertible
# 2. Payment options
# 3. Term length tradeoffs
# 4. Regional vs Zonal
# 5. Instance size flexibility

# %%
# %%ai $MODEL
# AWS Savings Plans:
# 1. Compute Savings Plans
# 2. EC2 Instance Savings Plans
# 3. SageMaker Savings Plans
# 4. Coverage vs utilization
# 5. Stacking with RIs

# %%
# %%ai $MODEL
# GCP Committed Use:
# 1. Committed use discounts
# 2. Sustained use discounts
# 3. Flexible commitments
# 4. Resource-based CUDs
# 5. Spend-based CUDs

# %%
# %%ai $MODEL
# Coverage analysis:
# 1. Historical usage patterns
# 2. RI coverage reports
# 3. Utilization tracking
# 4. Expiration management
# 5. Purchase recommendations

# %%
# %%ai $MODEL
# RI marketplace:
# 1. Selling unused RIs
# 2. Buying third-party RIs
# 3. Pricing strategies
# 4. Transfer restrictions
# 5. Marketplace alternatives

# %% [markdown]
# ---
#
# ## Summary
#
# Covered commitments:
# - Reserved Instances
# - Savings Plans
# - GCP Committed Use
# - Coverage analysis
# - RI marketplace
#
# ---
