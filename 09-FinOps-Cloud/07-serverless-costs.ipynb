# %% [markdown]
# # Serverless Cost Optimization
#
# **Category:** 09-FinOps-Cloud
# **Topic:** Lambda and serverless cost management
#
# ---
#
# ## Learning Objectives
# - Lambda pricing model
# - Memory optimization
# - Cold start costs
# - Serverless vs containers

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Lambda pricing:
# 1. Request pricing
# 2. Duration pricing (GB-seconds)
# 3. Provisioned concurrency
# 4. Free tier limits
# 5. Regional variations

# %%
# %%ai $MODEL
# Memory optimization:
# 1. Memory vs CPU scaling
# 2. AWS Lambda Power Tuning
# 3. Cost vs performance tradeoff
# 4. Optimal memory settings
# 5. Automated tuning

# %%
# %%ai $MODEL
# Cold start optimization:
# 1. Cold start cost impact
# 2. Provisioned concurrency
# 3. Keep-warm strategies
# 4. Package size optimization
# 5. SnapStart for Java

# %%
# %%ai $MODEL
# Serverless architectures:
# 1. API Gateway costs
# 2. Step Functions pricing
# 3. EventBridge costs
# 4. DynamoDB on-demand
# 5. Total cost modeling

# %%
# %%ai $MODEL
# When to use serverless:
# 1. Break-even analysis
# 2. Traffic patterns
# 3. Serverless vs EC2/ECS
# 4. Hybrid approaches
# 5. Migration considerations

# %% [markdown]
# ---
#
# ## Summary
#
# Covered serverless costs:
# - Lambda pricing
# - Memory optimization
# - Cold starts
# - Architecture costs
# - Decision framework
#
# ---
