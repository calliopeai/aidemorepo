# %% [markdown]
# # Cost Allocation & Tagging
#
# **Category:** 09-FinOps-Cloud
# **Topic:** Tracking and allocating costs
#
# ---
#
# ## Learning Objectives
# - Tagging strategies
# - Cost allocation tags
# - Chargeback models
# - Untagged resources

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Tagging strategy:
# 1. Essential tags (owner, project, environment)
# 2. Tag naming conventions
# 3. Required vs optional tags
# 4. Tag governance
# 5. Automation with policies

# %%
# %%ai $MODEL
# Cost allocation tags:
# 1. AWS cost allocation tags
# 2. User-defined vs AWS-generated
# 3. Activating tags
# 4. Cost and Usage Reports
# 5. Historical tag data

# %%
# %%ai $MODEL
# Chargeback and showback:
# 1. Chargeback models
# 2. Showback reporting
# 3. Shared costs allocation
# 4. Platform costs distribution
# 5. Internal pricing

# %%
# %%ai $MODEL
# Finding untagged resources:
# 1. AWS Resource Groups
# 2. Tag Editor
# 3. Config rules for tagging
# 4. Remediation automation
# 5. Compliance reporting

# %%
# %%ai $MODEL
# Cost attribution:
# 1. Per-team cost reports
# 2. Project-level tracking
# 3. Environment breakdown
# 4. Service-level costs
# 5. Unit economics

# %% [markdown]
# ---
#
# ## Summary
#
# Covered cost allocation:
# - Tagging strategy
# - Cost allocation tags
# - Chargeback/showback
# - Untagged resources
# - Cost attribution
#
# ---
