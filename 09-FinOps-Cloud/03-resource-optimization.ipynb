# %% [markdown]
# # Resource Optimization
#
# **Category:** 09-FinOps-Cloud
# **Topic:** Right-sizing and optimization
#
# ---
#
# ## Learning Objectives
# - Right-sizing instances
# - Idle resource detection
# - Storage optimization
# - Database cost optimization

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Right-sizing instances:
# 1. CPU and memory metrics
# 2. AWS Compute Optimizer
# 3. GCP Recommender
# 4. Azure Advisor
# 5. Automated right-sizing

# %%
# %%ai $MODEL
# Idle resource detection:
# 1. Unused EC2 instances
# 2. Detached EBS volumes
# 3. Unused elastic IPs
# 4. Idle load balancers
# 5. Zombie resources cleanup

# %%
# %%ai $MODEL
# Storage optimization:
# 1. S3 storage classes
# 2. Intelligent tiering
# 3. Lifecycle policies
# 4. EBS volume types
# 5. Data compression

# %%
# %%ai $MODEL
# Database optimization:
# 1. RDS instance sizing
# 2. Aurora Serverless
# 3. Reserved capacity
# 4. Read replicas cost
# 5. DynamoDB capacity modes

# %%
# %%ai $MODEL
# Containerization savings:
# 1. Kubernetes resource requests
# 2. Pod right-sizing
# 3. Cluster autoscaling
# 4. Spot/Preemptible nodes
# 5. Serverless containers

# %% [markdown]
# ---
#
# ## Summary
#
# Covered optimization:
# - Instance right-sizing
# - Idle resources
# - Storage
# - Databases
# - Containers
#
# ---
