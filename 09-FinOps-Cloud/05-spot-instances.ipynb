# %% [markdown]
# # Spot Instances & Preemptible VMs
#
# **Category:** 09-FinOps-Cloud
# **Topic:** Interruptible compute savings
#
# ---
#
# ## Learning Objectives
# - Spot instance mechanics
# - Workload suitability
# - Interruption handling
# - Mixed instance strategies

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Spot instance basics:
# 1. How spot pricing works
# 2. Savings potential (up to 90%)
# 3. Interruption mechanism
# 4. Spot capacity pools
# 5. Instance diversification

# %%
# %%ai $MODEL
# Suitable workloads:
# 1. Batch processing
# 2. CI/CD pipelines
# 3. Data analytics
# 4. Training ML models
# 5. Stateless web services

# %%
# %%ai $MODEL
# Interruption handling:
# 1. Termination notices
# 2. Checkpointing strategies
# 3. Graceful shutdown
# 4. Spot Instance Advisor
# 5. Capacity rebalancing

# %%
# %%ai $MODEL
# AWS Spot strategies:
# 1. Spot Fleet
# 2. EC2 Auto Scaling groups
# 3. Allocation strategies
# 4. Spot Blocks
# 5. Persistent requests

# %%
# %%ai $MODEL
# Kubernetes spot nodes:
# 1. Karpenter provisioner
# 2. Cluster Autoscaler spot
# 3. Node selectors
# 4. Pod disruption budgets
# 5. Spot in EKS/GKE

# %% [markdown]
# ---
#
# ## Summary
#
# Covered spot instances:
# - Spot basics
# - Workload selection
# - Interruption handling
# - AWS strategies
# - Kubernetes integration
#
# ---
