# %% [markdown]
# # Feature Engineering
#
# **Category:** 06-AI-ML
# **Topic:** Creating and selecting features
#
# ---
#
# ## Learning Objectives
# - Transform raw data into features
# - Handle categorical variables
# - Create interaction features
# - Select important features

# %%
# %pip install -q scikit-learn pandas numpy matplotlib seaborn category_encoders

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Categorical feature encoding:
# 1. One-hot encoding (when and how)
# 2. Label encoding
# 3. Target encoding (with regularization)
# 4. Binary encoding
# 5. Frequency encoding
#
# Compare impact on model performance.

# %%
# %%ai $MODEL
# Numerical feature transformations:
# 1. Standardization vs Normalization
# 2. Log transformation for skewed data
# 3. Box-Cox and Yeo-Johnson
# 4. Binning/discretization
# 5. Polynomial features
#
# Visualize distributions before/after.

# %%
# %%ai $MODEL
# Date/time feature engineering:
# 1. Extract components (year, month, day, hour)
# 2. Cyclical encoding for periodic features
# 3. Time since event features
# 4. Rolling window statistics
# 5. Holiday and weekend flags
#
# Apply to sample time series data.

# %%
# %%ai $MODEL
# Feature selection methods:
# 1. Filter methods (correlation, chi-square)
# 2. Wrapper methods (RFE)
# 3. Embedded methods (Lasso, tree importance)
# 4. Permutation importance
# 5. SHAP-based selection
#
# Compare results and computational cost.

# %%
# %%ai $MODEL
# Build a feature engineering pipeline:
# 1. Create sklearn ColumnTransformer
# 2. Handle missing values
# 3. Apply different transforms per column type
# 4. Create custom transformers
# 5. Integrate with model pipeline
#
# Make it reproducible and production-ready.

# %% [markdown]
# ---
#
# ## Summary
#
# Covered feature engineering:
# - Categorical encoding methods
# - Numerical transformations
# - Datetime features
# - Feature selection
# - Sklearn pipelines
#
# ---
