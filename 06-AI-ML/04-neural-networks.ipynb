# %% [markdown]
# # Neural Networks Fundamentals
#
# **Category:** 06-AI-ML
# **Topic:** Building neural networks with AI guidance
#
# ---
#
# ## Learning Objectives
# - Understand neural network architecture
# - Build models with TensorFlow/Keras
# - Train and evaluate networks
# - Prevent overfitting

# %%
# %pip install -q tensorflow numpy matplotlib scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Create a Keras classification model:
# 1. Load MNIST dataset
# 2. Preprocess images
# 3. Build Sequential model (Dense layers)
# 4. Compile with optimizer and loss
# 5. Train with validation split
# 6. Plot training curves
# 7. Evaluate on test set

# %%
# %%ai $MODEL
# Implement regularization techniques:
# - L1/L2 regularization
# - Dropout layers
# - Early stopping callback
# - Batch normalization
#
# Compare training with/without regularization.
# Show impact on overfitting.

# %%
# %%ai $MODEL
# Build a Convolutional Neural Network:
# 1. Conv2D and MaxPooling layers
# 2. Feature map visualization
# 3. Model architecture for CIFAR-10
# 4. Data augmentation
# 5. Training with callbacks
# 6. Confusion matrix analysis

# %%
# %%ai $MODEL
# Hyperparameter tuning for neural networks:
# - Learning rate scheduling
# - Batch size impact
# - Network depth vs width
# - Use Keras Tuner for search
# - Compare optimizers (SGD, Adam, RMSprop)

# %% [markdown]
# ---
#
# ## Summary
#
# Covered neural network topics:
# - From-scratch implementation
# - Keras/TensorFlow basics
# - Regularization techniques
# - CNNs for image data
# - Hyperparameter tuning
#
# ---
