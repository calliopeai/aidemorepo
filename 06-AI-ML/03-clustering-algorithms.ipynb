# %% [markdown]
# # Clustering Algorithms
#
# **Category:** 06-AI-ML
# **Topic:** Unsupervised learning with clustering
#
# ---
#
# ## Learning Objectives
# - Implement K-Means clustering
# - Use hierarchical clustering
# - Apply DBSCAN for density-based clustering
# - Evaluate cluster quality

# %%
# %pip install -q scikit-learn pandas numpy matplotlib seaborn

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Implement K-Means clustering:
# 1. Generate synthetic customer data (spending, frequency, recency)
# 2. Scale features appropriately
# 3. Use elbow method to find optimal K
# 4. Train K-Means model
# 5. Visualize clusters in 2D
# 6. Analyze cluster characteristics

# %%
# %%ai $MODEL
# Compare K-Means with hierarchical clustering:
# - Agglomerative clustering (ward, complete, average linkage)
# - Create dendrogram visualization
# - Cut tree at optimal level
# - Compare cluster assignments with K-Means
# - When to use each approach?

# %%
# %%ai $MODEL
# Apply DBSCAN for non-spherical clusters:
# 1. Generate data with arbitrary shapes (moons, circles)
# 2. Show why K-Means fails
# 3. Apply DBSCAN
# 4. Tune eps and min_samples
# 5. Handle noise points
# 6. Visualize results

# %%
# %%ai $MODEL
# Evaluate clustering quality:
# - Silhouette score
# - Calinski-Harabasz index
# - Davies-Bouldin index
# - Visualization of silhouette plots
# - Compare different algorithms on same data

# %%
# %%ai $MODEL
# Customer segmentation case study:
# - Create RFM (Recency, Frequency, Monetary) features
# - Normalize and cluster customers
# - Profile each segment
# - Visualize segments
# - Suggest marketing strategies per segment

# %% [markdown]
# ---
#
# ## Summary
#
# Covered clustering techniques:
# - K-Means and elbow method
# - Hierarchical clustering
# - DBSCAN for arbitrary shapes
# - Cluster evaluation metrics
# - Customer segmentation application
#
# ---
