# %% [markdown]
# # Ensemble Methods
#
# **Category:** 06-AI-ML
# **Topic:** Combining models for better performance
#
# ---
#
# ## Learning Objectives
# - Understand bagging and boosting
# - Implement Random Forest
# - Use gradient boosting methods
# - Create model stacking

# %%
# %pip install -q scikit-learn xgboost lightgbm catboost pandas numpy matplotlib

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Explain and implement bagging:
# 1. Bootstrap sampling concept
# 2. BaggingClassifier with decision trees
# 3. Out-of-bag error estimation
# 4. Compare with single tree
# 5. Variance reduction visualization

# %%
# %%ai $MODEL
# Random Forest in depth:
# 1. How it differs from bagging
# 2. Feature importance methods
# 3. Hyperparameter tuning (n_estimators, max_depth, etc.)
# 4. Handling class imbalance
# 5. Partial dependence plots
#
# Use a real dataset for demonstration.

# %%
# %%ai $MODEL
# Compare gradient boosting libraries:
# 1. XGBoost implementation
# 2. LightGBM implementation
# 3. CatBoost for categorical features
# 4. Performance comparison
# 5. Training time comparison
#
# Same hyperparameters, same dataset.

# %%
# %%ai $MODEL
# Advanced boosting techniques:
# 1. Early stopping implementation
# 2. Learning rate scheduling
# 3. Regularization parameters
# 4. Custom loss functions
# 5. GPU acceleration

# %%
# %%ai $MODEL
# Model stacking:
# 1. Build base models (RF, XGB, LogReg, SVM)
# 2. Create meta-learner
# 3. Use StackingClassifier from sklearn
# 4. Avoid data leakage with proper CV
# 5. Compare stacked vs individual models

# %% [markdown]
# ---
#
# ## Summary
#
# Covered ensemble methods:
# - Bagging fundamentals
# - Random Forest
# - Gradient boosting (XGBoost, LightGBM, CatBoost)
# - Advanced techniques
# - Model stacking
#
# ---
