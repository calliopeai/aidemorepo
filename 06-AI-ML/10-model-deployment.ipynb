# %% [markdown]
# # Model Deployment
#
# **Category:** 06-AI-ML
# **Topic:** Deploying ML models to production
#
# ---
#
# ## Learning Objectives
# - Save and load models
# - Create API endpoints
# - Containerize models
# - Monitor model performance

# %%
# %pip install -q scikit-learn joblib mlflow fastapi

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Model serialization:
# 1. Save with pickle and joblib
# 2. Save with ONNX for interoperability
# 3. TensorFlow SavedModel format
# 4. PyTorch model saving
# 5. Version your models

# %%
# %%ai $MODEL
# Create FastAPI prediction endpoint:
# 1. Load trained model
# 2. Create Pydantic input schema
# 3. Implement predict endpoint
# 4. Add input validation
# 5. Return probabilities and predictions
#
# Include error handling and logging.

# %%
# %%ai $MODEL
# Docker containerization:
# 1. Create Dockerfile for ML service
# 2. Multi-stage build for smaller image
# 3. Include model file
# 4. Docker Compose for dependencies
# 5. Best practices for ML containers

# %%
# %%ai $MODEL
# MLflow for experiment tracking:
# 1. Track experiments and parameters
# 2. Log metrics and artifacts
# 3. Model registry
# 4. Serve models with MLflow
# 5. Compare runs and select best

# %%
# %%ai $MODEL
# Production monitoring:
# 1. Data drift detection
# 2. Model performance decay
# 3. Prediction logging
# 4. A/B testing setup
# 5. Alerting on degradation

# %% [markdown]
# ---
#
# ## Summary
#
# Covered deployment topics:
# - Model serialization formats
# - FastAPI endpoints
# - Docker containerization
# - MLflow tracking
# - Production monitoring
#
# ---
