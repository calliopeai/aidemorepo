# %% [markdown]
# # Model Evaluation Techniques
#
# **Category:** 06-AI-ML
# **Topic:** Evaluating ML model performance
#
# ---
#
# ## Learning Objectives
# - Use cross-validation properly
# - Understand classification metrics
# - Analyze regression metrics
# - Handle imbalanced datasets

# %%
# %pip install -q scikit-learn pandas numpy matplotlib seaborn imbalanced-learn

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Implement cross-validation strategies:
# 1. K-Fold cross-validation
# 2. Stratified K-Fold for imbalanced data
# 3. Leave-One-Out
# 4. Time series split
# 5. Group K-Fold
#
# Show when to use each and compare results.

# %%
# %%ai $MODEL
# Comprehensive classification metrics:
# 1. Confusion matrix visualization
# 2. Accuracy, Precision, Recall, F1
# 3. ROC curve and AUC
# 4. Precision-Recall curve
# 5. Multi-class metrics (macro, micro, weighted)
#
# Use a real classification problem to demonstrate.

# %%
# %%ai $MODEL
# Regression evaluation metrics:
# 1. MAE, MSE, RMSE
# 2. R² and Adjusted R²
# 3. MAPE (Mean Absolute Percentage Error)
# 4. Residual analysis plots
# 5. Heteroscedasticity detection
#
# Include visualization of residuals.

# %%
# %%ai $MODEL
# Handle imbalanced classification:
# 1. Generate imbalanced dataset (1:100 ratio)
# 2. Show why accuracy is misleading
# 3. Apply SMOTE oversampling
# 4. Use class weights
# 5. Compare threshold adjustment
# 6. Use appropriate metrics

# %%
# %%ai $MODEL
# Model comparison framework:
# 1. Train multiple models on same data
# 2. Statistical comparison (McNemar's test)
# 3. Confidence intervals for metrics
# 4. Learning curves comparison
# 5. Create comprehensive evaluation report

# %% [markdown]
# ---
#
# ## Summary
#
# Covered evaluation techniques:
# - Cross-validation strategies
# - Classification metrics
# - Regression metrics
# - Imbalanced data handling
# - Model comparison
#
# ---
