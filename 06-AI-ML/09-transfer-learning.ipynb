# %% [markdown]
# # Transfer Learning
#
# **Category:** 06-AI-ML
# **Topic:** Leveraging pre-trained models
#
# ---
#
# ## Learning Objectives
# - Understand transfer learning concepts
# - Use pre-trained image models
# - Fine-tune for custom tasks
# - Apply to NLP tasks

# %%
# %pip install -q tensorflow transformers torch torchvision

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Explain transfer learning concepts:
# 1. What is transfer learning?
# 2. Feature extraction vs fine-tuning
# 3. When to use each approach
# 4. Domain adaptation
# 5. Negative transfer risks

# %%
# %%ai $MODEL
# Image classification with pre-trained models:
# 1. Load ResNet50 without top layers
# 2. Add custom classification head
# 3. Freeze base model layers
# 4. Train on custom dataset
# 5. Compare with training from scratch

# %%
# %%ai $MODEL
# Fine-tuning strategies:
# 1. Progressive unfreezing
# 2. Discriminative learning rates
# 3. Gradual layer unfreezing
# 4. Monitor for overfitting
# 5. Best practices for small datasets

# %%
# %%ai $MODEL
# Transfer learning for NLP:
# 1. Use HuggingFace transformers
# 2. Load pre-trained BERT
# 3. Fine-tune for text classification
# 4. Sentiment analysis example
# 5. Compare with traditional ML

# %%
# %%ai $MODEL
# Feature extraction for similarity:
# 1. Extract features from images using VGG/ResNet
# 2. Build image similarity search
# 3. Use cosine similarity
# 4. Create simple reverse image search
# 5. Visualize similar images

# %% [markdown]
# ---
#
# ## Summary
#
# Covered transfer learning:
# - Concepts and when to use
# - Pre-trained image models
# - Fine-tuning strategies
# - NLP with transformers
# - Feature extraction applications
#
# ---
