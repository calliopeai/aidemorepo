# %% [markdown]
# # Dimensionality Reduction
#
# **Category:** 06-AI-ML
# **Topic:** Reducing feature dimensions
#
# ---
#
# ## Learning Objectives
# - Apply PCA for linear reduction
# - Use t-SNE for visualization
# - Implement UMAP
# - Choose appropriate technique

# %%
# %pip install -q scikit-learn pandas numpy matplotlib seaborn umap-learn

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# PCA from scratch and sklearn:
# 1. Implement PCA using numpy (covariance, eigenvalues)
# 2. Compare with sklearn PCA
# 3. Explained variance ratio plot
# 4. Select optimal components
# 5. Visualize principal components

# %%
# %%ai $MODEL
# t-SNE for visualization:
# 1. Load MNIST digits
# 2. Apply t-SNE to reduce to 2D
# 3. Tune perplexity parameter
# 4. Color by class labels
# 5. Compare with PCA visualization
#
# Explain limitations (non-deterministic, no new data).

# %%
# %%ai $MODEL
# UMAP: faster alternative to t-SNE:
# 1. Install and configure UMAP
# 2. Compare speed with t-SNE
# 3. Preserve global structure
# 4. Parameter tuning (n_neighbors, min_dist)
# 5. Use for clustering preprocessing

# %%
# %%ai $MODEL
# Other dimensionality reduction techniques:
# 1. LDA for supervised reduction
# 2. Kernel PCA for non-linear
# 3. Truncated SVD for sparse data
# 4. Factor Analysis
# 5. Compare on same dataset

# %%
# %%ai $MODEL
# Practical application:
# 1. High-dimensional gene expression data
# 2. Apply PCA for noise reduction
# 3. Use reduced features for classification
# 4. Compare model performance (full vs reduced)
# 5. Visualize sample clusters

# %% [markdown]
# ---
#
# ## Summary
#
# Covered dimensionality reduction:
# - PCA theory and practice
# - t-SNE for visualization
# - UMAP as modern alternative
# - Other techniques (LDA, Kernel PCA)
# - Practical applications
#
# ---
