# %% [markdown]
# # Fixed Income Analysis
#
# **Category:** 11-Financial
# **Topic:** Bond analytics with AI
#
# ---
#
# ## Learning Objectives
# - Bond pricing
# - Yield calculations
# - Duration and convexity
# - Term structure

# %%
# %pip install -q numpy scipy pandas matplotlib

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Bond pricing:
# 1. Present value of cash flows
# 2. Coupon vs zero-coupon bonds
# 3. Price-yield relationship
# 4. Accrued interest
# 5. Clean vs dirty price

# %%
# %%ai $MODEL
# Yield measures:
# 1. Current yield
# 2. Yield to maturity (YTM)
# 3. Yield to call
# 4. Newton-Raphson for YTM
# 5. Yield curve plotting

# %%
# %%ai $MODEL
# Duration and convexity:
# 1. Macaulay duration
# 2. Modified duration
# 3. Price change estimation
# 4. Convexity calculation
# 5. Immunization strategies

# %%
# %%ai $MODEL
# Term structure models:
# 1. Nelson-Siegel model
# 2. Svensson extension
# 3. Bootstrap spot rates
# 4. Forward rate calculation
# 5. Curve fitting

# %%
# %%ai $MODEL
# Credit analysis:
# 1. Credit spread calculation
# 2. Default probability
# 3. Recovery rate
# 4. Credit rating migration
# 5. CDS pricing basics

# %% [markdown]
# ---
#
# ## Summary
#
# Covered fixed income:
# - Bond pricing
# - Yields
# - Duration/Convexity
# - Term structure
# - Credit analysis
#
# ---
