# %% [markdown]
# # Quantitative Financial Analysis
#
# **Category:** 11-Financial
# **Topic:** Quantitative finance with AI
#
# ---
#
# ## Learning Objectives
# - Factor models
# - Statistical arbitrage
# - Pairs trading
# - Alpha generation

# %%
# %pip install -q pandas numpy statsmodels yfinance matplotlib

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Factor models:
# 1. CAPM (Capital Asset Pricing Model)
# 2. Fama-French 3-factor model
# 3. Factor exposure calculation
# 4. Alpha and beta estimation
# 5. Factor attribution

# %%
# %%ai $MODEL
# Pairs trading:
# 1. Find cointegrated pairs
# 2. Spread calculation
# 3. Z-score trading signals
# 4. Entry and exit rules
# 5. Backtesting strategy

# %%
# %%ai $MODEL
# Mean reversion strategies:
# 1. Mean reversion detection
# 2. Bollinger Bands strategy
# 3. RSI-based trading
# 4. Half-life estimation
# 5. Position sizing

# %%
# %%ai $MODEL
# Momentum strategies:
# 1. Cross-sectional momentum
# 2. Time-series momentum
# 3. Dual momentum
# 4. Momentum crash risk
# 5. Implementation in Python

# %%
# %%ai $MODEL
# Strategy backtesting:
# 1. Walk-forward optimization
# 2. Transaction costs
# 3. Slippage modeling
# 4. Performance metrics (Sharpe, Sortino)
# 5. Monte Carlo simulation

# %% [markdown]
# ---
#
# ## Summary
#
# Covered quant analysis:
# - Factor models
# - Pairs trading
# - Mean reversion
# - Momentum
# - Backtesting
#
# ---
