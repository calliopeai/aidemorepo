# %% [markdown]
# # Machine Learning in Finance
#
# **Category:** 11-Financial
# **Topic:** ML for financial prediction
#
# ---
#
# ## Learning Objectives
# - Feature engineering for finance
# - Price prediction models
# - Time series ML
# - Avoiding overfitting

# %%
# %pip install -q pandas numpy scikit-learn xgboost matplotlib

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Financial feature engineering:
# 1. Technical indicators as features
# 2. Lag features
# 3. Rolling statistics
# 4. Return transformations
# 5. Volatility features

# %%
# %%ai $MODEL
# Direction prediction:
# 1. Binary classification (up/down)
# 2. Feature selection
# 3. Random Forest classifier
# 4. XGBoost classifier
# 5. Probability calibration

# %%
# %%ai $MODEL
# Time series cross-validation:
# 1. Why standard CV fails
# 2. Walk-forward validation
# 3. Expanding window
# 4. Sliding window
# 5. Purged k-fold

# %%
# %%ai $MODEL
# Avoiding overfitting:
# 1. Look-ahead bias
# 2. Survivorship bias
# 3. Multiple testing problem
# 4. Regularization
# 5. Out-of-sample testing

# %%
# %%ai $MODEL
# Alternative data:
# 1. Sentiment from news
# 2. Social media signals
# 3. Satellite imagery
# 4. Web scraping data
# 5. Feature combination

# %% [markdown]
# ---
#
# ## Summary
#
# Covered financial ML:
# - Feature engineering
# - Direction prediction
# - Time series CV
# - Avoiding biases
# - Alternative data
#
# ---
