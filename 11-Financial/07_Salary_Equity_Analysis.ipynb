# %% [markdown]
# # 💰 Salary Analysis - Equity, Clustering & Compensation Intelligence
# ## Pay Gap Analysis, Career Trajectory Modeling, Hierarchical Clustering & Fairness Metrics
#
# **Data:** `~/lab/data/CSVs/Average_Salary_by_Job_Classification.csv`
#
# ### Exotic Techniques:
# - 📊 Lorenz curves & Gini coefficient for inequality
# - 🌳 Hierarchical clustering of job families
# - 🎯 Principal Component Analysis for job similarity
# - 📈 Quantile regression for salary bands
# - 🔍 Outlier detection (underpaid/overpaid)
# - 🌐 Network analysis of career paths
# - 📉 Pay dispersion analysis by level
# - 🎨 Treemap visualization of org structure
# - 🧮 Market positioning (percentile analysis)
# - ⚖️ Fairness metrics & bias detection

# %% [markdown]
# ## 1. Load & Feature Engineering

# %%
# %%calliope ask gpto --format code
# Load ~/lab/data/CSVs/Average_Salary_by_Job_Classification.csv
#
# Clean column names.
# Engineer features:
# - Job level/tier (extract from title if possible)
# - Department/function
# - Seniority indicators (keywords: junior, senior, lead, director)
# - Salary percentile within department
# - Z-score (standardized salary)
#
# Display:
# - Dataset shape and columns
# - Salary statistics (min, max, mean, median, std)
# - Top 20 highest paid jobs
# - Department breakdown
# - Missing values
#
# Store as 'salary_df'.

# %% [markdown]
# ## 2. Inequality Analysis: Lorenz Curve & Gini

# %%
# %%calliope ask anthropic-chat:claude-opus-4-20250514 --format code
# Using salary_df:
#
# Measure salary inequality:
# 1. Calculate cumulative distribution of salaries
# 2. Create Lorenz curve:
#    - X-axis: Cumulative % of employees
#    - Y-axis: Cumulative % of total salary
#    - Add 45° line (perfect equality)
# 3. Calculate Gini coefficient (area between curves)
# 4. Compare inequality across:
#    - Departments
#    - Job levels
#    - Functions
# 5. Create multiple Lorenz curves (one per department)
# 6. Calculate Palma ratio (top 10% vs bottom 40%)
# 7. Create interactive plotly visualization
#
# Print Gini coefficients and interpret (0=perfect equality, 1=perfect inequality).

# %% [markdown]
# ## 3. Hierarchical Clustering of Job Roles

# %%
# %%calliope ask openai-chat:gpt-5 --format code
# Using salary_df:
#
# Cluster similar jobs:
# 1. Create feature matrix from:
#    - Salary
#    - Department
#    - Job title (TF-IDF vectorization)
#    - Benefits if available
# 2. Standardize features
# 3. Apply hierarchical clustering (Ward linkage)
# 4. Create dendrogram with plotly:
#    - Interactive tree visualization
#    - Color branches by cluster
#    - Show job titles at leaves
# 5. Determine optimal number of clusters (elbow, silhouette)
# 6. Analyze each cluster:
#    - Mean salary
#    - Common job characteristics
#    - Size
# 7. Create cluster profile dashboard
#
# Store cluster assignments in salary_df.

# %% [markdown]
# ## 4. PCA for Job Similarity Landscape

# %%
# %%calliope ask gemini:gemini-2.5-pro --format code
# Using salary_df with features:
#
# Create 2D job landscape:
# 1. Apply PCA to reduce to 2 dimensions
# 2. Create interactive scatter plot:
#    - Points = jobs
#    - X/Y = PC1/PC2
#    - Color by: salary (gradient) or department
#    - Size by: number of employees or salary range
# 3. Add hover showing:
#    - Job title
#    - Salary
#    - Department
#    - Cluster membership
# 4. Overlay cluster boundaries (convex hulls)
# 5. Add vector overlay showing:
#    - Which original features drive each PC
# 6. Explain variance captured by each PC
#
# Beautiful visualization revealing job structure.

# %% [markdown]
# ## 5. Quantile Regression for Salary Bands

# %%
# %%calliope ask anthropic-chat:claude-sonnet-4-5-20250929 --format code
# Using salary_df:
#
# Model salary bands:
# 1. Predict salary using job features
# 2. Train quantile regression for:
#    - 10th, 25th, 50th, 75th, 90th percentiles
# 3. Create salary band visualization:
#    - Jobs ordered by median salary
#    - Shaded bands showing percentile ranges
#    - Actual salaries as scatter points
# 4. Identify outliers:
#    - Jobs above 90th percentile (overpaid?)
#    - Jobs below 10th percentile (underpaid?)
# 5. Market competitiveness analysis:
#    - Compare actual to market bands
# 6. Create interactive plot with:
#    - Filter by department
#    - Hover details
#
# Store outliers for equity review.

# %% [markdown]
# ## 6. Career Path Network Analysis

# %%
# %%calliope ask openai-chat:gpt-4o --format code
# Using salary_df and job hierarchies:
#
# Build career progression network:
# 1. Infer job relationships from:
#    - Salary progression
#    - Title similarity
#    - Department structure
# 2. Create directed graph:
#    - Nodes = job roles
#    - Edges = typical career moves
#    - Edge weight = salary delta
# 3. Calculate network metrics:
#    - In-degree: how many paths lead here
#    - Out-degree: promotion opportunities
#    - Betweenness: which jobs are career bridges
# 4. Visualize with plotly network graph:
#    - Hierarchical layout (by salary level)
#    - Node size = number of employees
#    - Node color = department
#    - Edge color = salary increase
# 5. Identify:
#    - Dead-end roles
#    - Key progression bottlenecks
#    - High-growth paths
#
# Interactive career path explorer.

# %% [markdown]
# ## 7. Pay Dispersion Analysis

# %%
# %%calliope ask cohere:command-r-plus-08-2024 --format code
# Using salary_df:
#
# Analyze salary dispersion:
# 1. Calculate for each job/department:
#    - Range (max - min)
#    - Interquartile range (IQR)
#    - Coefficient of variation (CV = std/mean)
#    - Gini coefficient
# 2. Compare dispersion across:
#    - Job levels (do senior roles have more spread?)
#    - Departments
#    - Functions
# 3. Visualizations:
#    - Box plots by department (show dispersion)
#    - Violin plots by level
#    - Scatter: mean salary vs CV
#    - Heatmap: department x level showing dispersion
# 4. Statistical tests:
#    - Levene test (equal variances?)
#    - Which groups have significantly different spreads?
#
# Identify groups with high/low pay consistency.

# %% [markdown]
# ## 8. Treemap of Organization Structure

# %%
# %%calliope ask gemini:gemini-2.0-flash --format code
# Using salary_df:
#
# Create hierarchical treemap:
# 1. Build hierarchy: Department → Level → Job Title
# 2. Plotly treemap with:
#    - Size = total compensation (or headcount)
#    - Color = average salary (gradient)
# 3. Interactive features:
#    - Click to drill down
#    - Hover showing:
#      • Job count
#      • Avg salary
#      • Total payroll
#      • % of org budget
# 4. Add sunburst alternative view
# 5. Create second treemap colored by:
#    - Pay equity score
#    - Market competitiveness
#
# Visual representation of compensation structure.

# %% [markdown]
# ## 9. Market Positioning & Percentile Analysis

# %%
# %%calliope ask mistralai:mistral-large-latest --format code
# Using salary_df:
#
# Benchmark against internal market:
# 1. For each job, calculate:
#    - Percentile rank within department
#    - Percentile rank within job family
#    - Percentile rank overall
# 2. Create compensation ratio:
#    - Actual salary / midpoint of range
#    - <1: below market, >1: above market
# 3. Visualize distribution:
#    - Histogram of compensation ratios
#    - Scatter: tenure vs comp ratio
#    - Box plot by department
# 4. Identify correction opportunities:
#    - Long tenure + low ratio = compression
#    - New hire + high ratio = overpaid
# 5. Budget impact analysis:
#    - Cost to bring all to 50th percentile
#    - Cost to bring underpaid to minimum
#
# Strategic compensation planning insights.

# %% [markdown]
# ## 10. Fairness Metrics & Bias Detection

# %%
# %%calliope ask anthropic-chat:claude-3-7-sonnet-20250219 --format code
# Using salary_df (if demographic data available):
#
# Analyze pay equity:
# 1. Control for legitimate factors:
#    - Job level
#    - Department
#    - Experience/tenure
#    - Performance
# 2. Test for unexplained gaps by:
#    - Gender (if data available)
#    - Other protected characteristics
# 3. Regression analysis:
#    - Model salary with controls
#    - Test significance of demographic variables
#    - Calculate adjusted pay gaps
# 4. Visualizations:
#    - Unadjusted vs adjusted gaps
#    - Distribution overlays by group
#    - Gap by job level/department
# 5. Statistical significance testing
# 6. If no demographic data:
#    - Analyze unexplained variance
#    - Flag anomalous patterns
#
# Ethical pay analysis framework.

# %% [markdown]
# ## 11. Executive Dashboard & Recommendations

# %%
# %%calliope ask gpto --format code
# Create comprehensive compensation dashboard:
#
# 1. Key metrics panel:
#    - Median salary
#    - Gini coefficient
#    - % jobs outside bands
#    - Total payroll
# 2. Interactive visualizations (3x3 grid):
#    - Lorenz curve
#    - Treemap
#    - Scatter (PCA)
#    - Salary bands
#    - Dispersion by dept
#    - Career paths network
#    - Comp ratio distribution
#    - Market positioning
#    - Outliers list
# 3. Recommendations section:
#    - Top 10 equity concerns
#    - Budget needed for corrections
#    - Risk areas
# 4. Export as HTML: 'compensation_intelligence_report.html'
#
# Executive-ready analytics.
