# %% [markdown]
# # Cryptocurrency Analysis
#
# **Category:** 11-Financial
# **Topic:** Crypto market analysis with AI
#
# ---
#
# ## Learning Objectives
# - Crypto data sources
# - Market analysis
# - DeFi metrics
# - On-chain analytics

# %%
# %pip install -q pandas numpy matplotlib yfinance

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Crypto data access:
# 1. Yahoo Finance crypto tickers
# 2. CoinGecko API
# 3. Historical price data
# 4. Market cap data
# 5. Volume analysis

# %%
# %%ai $MODEL
# Crypto market metrics:
# 1. Market dominance
# 2. Total market cap
# 3. Fear & Greed index
# 4. Correlation with BTC
# 5. Alt season indicators

# %%
# %%ai $MODEL
# Volatility analysis:
# 1. Historical volatility
# 2. Realized vs implied
# 3. Cross-asset comparison
# 4. Volatility regime detection
# 5. Risk-adjusted returns

# %%
# %%ai $MODEL
# DeFi metrics:
# 1. Total Value Locked (TVL)
# 2. Yield farming APY
# 3. Liquidity pool analysis
# 4. Gas price optimization
# 5. Impermanent loss calculation

# %%
# %%ai $MODEL
# Portfolio with crypto:
# 1. BTC as portfolio asset
# 2. Correlation benefits
# 3. Position sizing
# 4. Rebalancing strategies
# 5. Risk management

# %% [markdown]
# ---
#
# ## Summary
#
# Covered crypto analysis:
# - Data sources
# - Market metrics
# - Volatility
# - DeFi
# - Portfolio integration
#
# ---
