# %% [markdown]
# # RAG: Control Systems Theory
#
# **Category:** 04-RAG-Documents
# **PDF:** On The General Theory of Control Systems.pdf
# **Topic:** Classical control theory foundations
#
# ---
#
# ## About the Document
# Foundational paper on control systems theory: feedback, stability, and system dynamics.

# %%
# %pip install -q pymupdf

CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
import fitz
from pathlib import Path

PDF_PATH = Path.home() / 'lab' / 'data' / 'PDFs' / 'On The General Theory of Control Systems.pdf'

doc = fitz.open(PDF_PATH)
print(f"Pages: {len(doc)}")
doc.close()

# %%
# %%ai $MODEL
# Explain fundamental control theory concepts:
#
# 1. What is a feedback control system?
# 2. What is stability in control systems?
# 3. What is the transfer function?
# 4. Explain PID control (Proportional-Integral-Derivative)
# 5. What is the Nyquist stability criterion?

# %%
# %%ai $MODEL
# Modern control applications:
#
# 1. How are control systems used in robotics?
# 2. What is model predictive control (MPC)?
# 3. How does adaptive control work?
# 4. What's the relationship between control theory and reinforcement learning?
# 5. How are control systems used in autonomous vehicles?

# %% [markdown]
# ---
#
# ## Summary
#
# Covered control theory fundamentals:
# - Feedback systems
# - Stability analysis
# - PID control
# - Modern applications (robotics, autonomous systems)
#
# ---
