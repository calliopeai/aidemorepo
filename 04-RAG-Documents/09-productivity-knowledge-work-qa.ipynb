# %% [markdown]
# # RAG: Mise-en-Place for Knowledge Workers
#
# **Category:** 04-RAG-Documents
# **PDF:** Mise-en-Place for Knowledge Workers_ 6 Practices for Working Clean - Forte Labs.pdf
# **Topic:** Productivity and knowledge management
#
# ---
#
# ## About the Document
# Tiago Forte's guide to applying restaurant kitchen organization principles (mise-en-place) to knowledge work.

# %%
# %pip install -q pymupdf

CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
import fitz
from pathlib import Path

PDF_PATH = Path.home() / 'lab' / 'data' / 'PDFs' / 'Mise-en-Place for Knowledge Workers_ 6 Practices for Working Clean - Forte Labs.pdf'

doc = fitz.open(PDF_PATH)
print(f"Pages: {len(doc)}")
doc.close()

# %%
# %%ai $MODEL
# From Mise-en-Place for Knowledge Workers:
#
# 1. What is mise-en-place and how does it apply to knowledge work?
# 2. What are the 6 practices for "working clean"?
# 3. How do you organize your digital workspace?
# 4. What is the second brain concept?
# 5. How do you capture and process information effectively?

# %%
# %%ai $MODEL
# Knowledge work productivity:
#
# 1. How do you avoid context switching costs?
# 2. What's the relationship between organization and creativity?
# 3. How do you build sustainable productivity habits?
# 4. What tools support knowledge management?
# 5. How do you balance capture vs action?

# %% [markdown]
# ---
#
# ## Summary
#
# Explored knowledge work productivity:
# - Mise-en-place principles
# - Digital organization
# - Second brain methodology
# - Sustainable productivity
#
# ---
