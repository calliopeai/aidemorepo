# %% [markdown]
# # RAG: O'Reilly Observability Engineering
#
# **Category:** 04-RAG-Documents
# **PDF:** Honeycomb-OReilly-Book-on-Observability-Engineering.pdf
# **Topic:** Modern observability practices
#
# ---
#
# ## About the Book
# Comprehensive guide to observability engineering: understanding, debugging, and improving complex distributed systems.

# %%
# %pip install -q pymupdf chromadb sentence-transformers

CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
import fitz
from pathlib import Path

PDF_PATH = Path.home() / 'lab' / 'data' / 'PDFs' / 'Honeycomb-OReilly-Book-on-Observability-Engineering.pdf'

# %%
doc = fitz.open(PDF_PATH)
pages = []
for i, page in enumerate(doc):
    text = page.get_text()
    if len(text) > 100:
        pages.append({'page': i+1, 'text': text})
doc.close()

print(f"Extracted {len(pages)} pages")

# %%
# %%ai $MODEL
# From the Observability Engineering book:
#
# 1. What is the difference between monitoring and observability?
# 2. What are the three pillars of observability (logs, metrics, traces)?
# 3. How do structured events differ from traditional logs?
# 4. What is high-cardinality data and why does it matter?
# 5. How does observability help with debugging in production?

# %%
# %%ai $MODEL
# Advanced observability concepts:
#
# 1. What is distributed tracing and how does it work?
# 2. How do you instrument code for observability?
# 3. What's the role of sampling in high-volume systems?
# 4. How does observability-driven development work?
# 5. What SLOs/SLIs should you track?

# %% [markdown]
# ---
#
# ## Summary
#
# Explored observability engineering concepts:
# - Observability vs monitoring
# - Three pillars (logs, metrics, traces)
# - Distributed tracing
# - Instrumentation best practices
#
# ---
