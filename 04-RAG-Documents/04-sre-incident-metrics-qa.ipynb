# %% [markdown]
# # RAG: SRE Incident Metrics
#
# **Category:** 04-RAG-Documents
# **PDF:** incident_metrics_in_sre.pdf
# **Topic:** Measuring and improving incident response
#
# ---
#
# ## About the Document
# Guide to incident metrics for Site Reliability Engineering: MTTD, MTTR, and incident management KPIs.

# %%
# %pip install -q pymupdf

CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
import fitz
from pathlib import Path

PDF_PATH = Path.home() / 'lab' / 'data' / 'PDFs' / 'incident_metrics_in_sre.pdf'

doc = fitz.open(PDF_PATH)
full_text = ""
for page in doc:
    full_text += page.get_text()
doc.close()

print(f"Document length: {len(full_text):,} characters")
print(full_text[:2000])

# %%
# %%ai $MODEL
# From SRE incident metrics documentation:
#
# 1. What is MTTD (Mean Time to Detect) and how do you improve it?
# 2. What is MTTR (Mean Time to Resolve/Recover)?
# 3. What other incident metrics are important?
# 4. How do you conduct effective postmortems?
# 5. What's the relationship between SLOs and incidents?

# %%
# %%ai $MODEL
# Incident management best practices:
#
# 1. How do you prioritize incidents (P1, P2, P3)?
# 2. What roles are needed in incident response?
# 3. How do you reduce alert fatigue?
# 4. What's a blameless postmortem culture?
# 5. How do you track improvement over time?

# %% [markdown]
# ---
#
# ## Summary
#
# Covered SRE incident metrics:
# - MTTD, MTTR, MTTA
# - Incident prioritization
# - Postmortem practices
# - Continuous improvement
#
# ---
