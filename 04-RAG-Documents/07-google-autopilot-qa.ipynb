# %% [markdown]
# # RAG: Google Autopilot Paper
#
# **Category:** 04-RAG-Documents
# **PDF:** Google Autopilot 3342195.3387524.pdf
# **Topic:** ML-based cluster management
#
# ---
#
# ## About the Paper
# Autopilot: workload autoscaling at Google Scale - using ML for resource management.

# %%
# %pip install -q pymupdf

CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
import fitz
from pathlib import Path

PDF_PATH = Path.home() / 'lab' / 'data' / 'PDFs' / 'Google Autopilot 3342195.3387524.pdf'

doc = fitz.open(PDF_PATH)
print(f"Pages: {len(doc)}")
doc.close()

# %%
# %%ai $MODEL
# From the Google Autopilot paper:
#
# 1. What is Autopilot and how does it relate to Borg?
# 2. How does Autopilot use ML for resource recommendations?
# 3. What's the difference between horizontal and vertical autoscaling?
# 4. How does Autopilot handle the cold-start problem?
# 5. What were the production results/benefits?

# %%
# %%ai $MODEL
# ML in infrastructure:
#
# 1. How can ML improve resource efficiency in cloud computing?
# 2. What features are used to predict resource needs?
# 3. How do you balance accuracy vs responsiveness in autoscaling?
# 4. What are the challenges of ML in production systems?
# 5. How does this relate to Kubernetes HPA/VPA?

# %% [markdown]
# ---
#
# ## Summary
#
# Explored Google Autopilot:
# - ML-based autoscaling
# - Resource prediction
# - Integration with Borg
# - Production lessons learned
#
# ---
