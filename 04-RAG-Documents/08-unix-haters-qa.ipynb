# %% [markdown]
# # RAG: Unix Haters Handbook
#
# **Category:** 04-RAG-Documents
# **PDF:** Unix Haters Handbook.pdf
# **Topic:** Classic critique of Unix design decisions
#
# ---
#
# ## About the Book
# A humorous but insightful critique of Unix, highlighting design flaws and usability issues from the early days.

# %%
# %pip install -q pymupdf

CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
import fitz
from pathlib import Path

PDF_PATH = Path.home() / 'lab' / 'data' / 'PDFs' / 'Unix Haters Handbook.pdf'

doc = fitz.open(PDF_PATH)
print(f"Pages: {len(doc)}")
doc.close()

# %%
# %%ai $MODEL
# From the Unix Haters Handbook perspective:
#
# 1. What were the main criticisms of Unix in the early days?
# 2. What usability issues did users face?
# 3. What problems exist with Unix file naming conventions?
# 4. What were the complaints about the shell and command line?
# 5. How do modern Unix systems address these concerns?

# %%
# %%ai $MODEL
# Unix philosophy and evolution:
#
# 1. What is the Unix philosophy ("do one thing well")?
# 2. What were the original design goals of Unix?
# 3. How has Linux addressed some of the historical criticisms?
# 4. What modern tools have improved Unix usability?
# 5. What lessons can system designers learn from Unix history?

# %% [markdown]
# ---
#
# ## Summary
#
# Explored Unix history and criticisms:
# - Historical usability issues
# - Design philosophy debates
# - Evolution of Unix/Linux
# - System design lessons
#
# ---
