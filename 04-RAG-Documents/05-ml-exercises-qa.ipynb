# %% [markdown]
# # RAG: ML Pen & Paper Exercises
#
# **Category:** 04-RAG-Documents
# **PDF:** Pen & Paper exercises in machine learning2206.13446.pdf
# **Topic:** Mathematical foundations of ML
#
# ---
#
# ## About the Document
# Collection of mathematical exercises for understanding ML algorithms from first principles.

# %%
# %pip install -q pymupdf

CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
import fitz
from pathlib import Path

PDF_PATH = Path.home() / 'lab' / 'data' / 'PDFs' / 'Pen & Paper exercises in machine learning2206.13446.pdf'

doc = fitz.open(PDF_PATH)
print(f"Pages: {len(doc)}")
doc.close()

# %%
# %%ai $MODEL
# For ML mathematical foundations:
#
# 1. Derive the gradient descent update rule
# 2. Explain the math behind linear regression's closed-form solution
# 3. How does backpropagation compute gradients?
# 4. What is the softmax function and why is it used?
# 5. Explain the bias-variance tradeoff mathematically

# %%
# %%ai $MODEL
# Advanced ML math concepts:
#
# 1. How do SVMs find the optimal hyperplane?
# 2. What is the kernel trick?
# 3. Explain the ELBO in variational inference
# 4. How does attention mechanism work mathematically?
# 5. What is the relationship between MLE and cross-entropy loss?

# %% [markdown]
# ---
#
# ## Summary
#
# Explored mathematical foundations:
# - Gradient descent derivation
# - Backpropagation
# - SVMs and kernel methods
# - Attention mechanisms
#
# ---
