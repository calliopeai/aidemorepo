# %% [markdown]
# # RAG: Princeton Companion to Mathematics
#
# **Category:** 04-RAG-Documents
# **PDF:** the Princeton Companion to Mathematics.pdf
# **Topic:** Comprehensive mathematics reference
#
# ---
#
# ## About the Book
# Encyclopedic reference covering major areas of pure and applied mathematics, written by leading mathematicians.

# %%
# %pip install -q pymupdf

CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
import fitz
from pathlib import Path

PDF_PATH = Path.home() / 'lab' / 'data' / 'PDFs' / 'the Princeton Companion to Mathematics.pdf'

doc = fitz.open(PDF_PATH)
print(f"Pages: {len(doc)}")
doc.close()

# %%
# %%ai $MODEL
# Major areas of mathematics:
#
# 1. What are the main branches of pure mathematics?
# 2. How is algebra connected to geometry?
# 3. What is number theory and why is it called "Queen of Mathematics"?
# 4. What are the major unsolved problems in mathematics?
# 5. How has mathematics evolved in the 20th/21st century?

# %%
# %%ai $MODEL
# Mathematics in computing and AI:
#
# 1. What is the role of linear algebra in machine learning?
# 2. How is probability theory fundamental to AI?
# 3. What is computational complexity theory?
# 4. How does category theory apply to programming?
# 5. What mathematical foundations underlie cryptography?

# %% [markdown]
# ---
#
# ## Summary
#
# Explored mathematical foundations:
# - Major mathematical branches
# - Connections between areas
# - Applications to computing
# - Current research frontiers
#
# ---
