# %% [markdown]
# # Service Mesh
#
# **Category:** 07-DevOps
# **Topic:** Istio and service mesh patterns
#
# ---
#
# ## Learning Objectives
# - Service mesh concepts
# - Istio architecture
# - Traffic management
# - Security features

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Service mesh concepts:
# 1. What is a service mesh
# 2. Sidecar proxy pattern
# 3. Data plane vs control plane
# 4. Why use a service mesh
# 5. Tradeoffs and complexity

# %%
# %%ai $MODEL
# Istio architecture:
# 1. Envoy proxy
# 2. Istiod control plane
# 3. Ingress/Egress gateways
# 4. Installation options
# 5. Resource requirements

# %%
# %%ai $MODEL
# Traffic management:
# 1. VirtualService routing
# 2. DestinationRule policies
# 3. Canary deployments
# 4. A/B testing
# 5. Circuit breaking

# %%
# %%ai $MODEL
# Istio security:
# 1. mTLS between services
# 2. AuthorizationPolicy
# 3. PeerAuthentication
# 4. JWT validation
# 5. Network policies

# %%
# %%ai $MODEL
# Observability with Istio:
# 1. Built-in metrics
# 2. Kiali dashboard
# 3. Distributed tracing
# 4. Access logging
# 5. Troubleshooting tips

# %% [markdown]
# ---
#
# ## Summary
#
# Covered service mesh:
# - Service mesh concepts
# - Istio architecture
# - Traffic management
# - Security features
# - Observability
#
# ---
