# %% [markdown]
# # Container Orchestration
#
# **Category:** 07-DevOps
# **Topic:** Docker and Kubernetes basics
#
# ---
#
# ## Learning Objectives
# - Understand containerization
# - Docker commands and best practices
# - Kubernetes fundamentals
# - Helm charts basics

# %%
# =============================================================================
# AUTO-INSTALL DEPENDENCIES
# Run this cell to scan the notebook and install required packages
# =============================================================================
# %%calliope ask claude --format code
Scan this notebook for all Python imports and library dependencies.
Generate a shell script that:
1. Checks if each required package is installed
2. Installs any missing packages using pip
Output only the executable shell commands, no explanations.

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Docker fundamentals:
# 1. Images vs containers
# 2. Dockerfile best practices
# 3. Multi-stage builds
# 4. Layer caching optimization
# 5. Security considerations

# %%
# %%ai $MODEL
# Docker Compose:
# 1. Multi-container applications
# 2. Service definitions
# 3. Networking between containers
# 4. Volume management
# 5. Environment variables

# %%
# %%ai $MODEL
# Kubernetes architecture:
# 1. Control plane components
# 2. Worker node components
# 3. Pods, Deployments, Services
# 4. ConfigMaps and Secrets
# 5. Namespaces

# %%
# %%ai $MODEL
# Kubernetes deployments:
# 1. Deployment strategies (rolling, blue-green)
# 2. Resource limits and requests
# 3. Health checks (liveness, readiness)
# 4. Horizontal Pod Autoscaler
# 5. Pod disruption budgets

# %%
# %%ai $MODEL
# Helm package manager:
# 1. What is Helm
# 2. Chart structure
# 3. Values and templates
# 4. Install/upgrade releases
# 5. Common Helm charts

# %% [markdown]
# ---
#
# ## Summary
#
# Covered container orchestration:
# - Docker fundamentals
# - Docker Compose
# - Kubernetes architecture
# - Deployments and scaling
# - Helm charts
#
# ---
