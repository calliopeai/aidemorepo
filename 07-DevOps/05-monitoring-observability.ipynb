# %% [markdown]
# # Monitoring and Observability
#
# **Category:** 07-DevOps
# **Topic:** Metrics, logs, and traces
#
# ---
#
# ## Learning Objectives
# - Three pillars of observability
# - Prometheus metrics
# - Logging best practices
# - Distributed tracing

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Three pillars of observability:
# 1. Metrics (what)
# 2. Logs (why)
# 3. Traces (where)
# 4. How they complement each other
# 5. Correlation between pillars

# %%
# %%ai $MODEL
# Prometheus and Grafana:
# 1. Metric types (counter, gauge, histogram)
# 2. PromQL basics
# 3. Alerting rules
# 4. Grafana dashboards
# 5. Application instrumentation

# %%
# %%ai $MODEL
# Structured logging:
# 1. JSON log format
# 2. Log levels and when to use
# 3. Contextual logging
# 4. ELK stack overview
# 5. Log aggregation patterns

# %%
# %%ai $MODEL
# Distributed tracing:
# 1. Trace, span, context
# 2. OpenTelemetry
# 3. Jaeger/Zipkin
# 4. Trace propagation
# 5. Sampling strategies

# %%
# %%ai $MODEL
# SRE practices:
# 1. SLIs, SLOs, SLAs
# 2. Error budgets
# 3. Incident response
# 4. On-call best practices
# 5. Post-mortems

# %% [markdown]
# ---
#
# ## Summary
#
# Covered observability:
# - Three pillars
# - Prometheus/Grafana
# - Structured logging
# - Distributed tracing
# - SRE practices
#
# ---
