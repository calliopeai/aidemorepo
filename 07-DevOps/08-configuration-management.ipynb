# %% [markdown]
# # Configuration Management
#
# **Category:** 07-DevOps
# **Topic:** Ansible and configuration management
#
# ---
#
# ## Learning Objectives
# - Configuration management concepts
# - Ansible basics
# - Playbooks and roles
# - Inventory management

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Configuration management:
# 1. What is configuration management
# 2. Push vs pull models
# 3. Idempotent operations
# 4. Desired state configuration
# 5. CM vs IaC

# %%
# %%ai $MODEL
# Ansible fundamentals:
# 1. Agentless architecture
# 2. YAML syntax
# 3. Modules overview
# 4. Ad-hoc commands
# 5. Connection methods

# %%
# %%ai $MODEL
# Ansible playbooks:
# 1. Playbook structure
# 2. Tasks and handlers
# 3. Variables and facts
# 4. Conditionals and loops
# 5. Templates with Jinja2

# %%
# %%ai $MODEL
# Ansible roles:
# 1. Role directory structure
# 2. defaults vs vars
# 3. Role dependencies
# 4. Ansible Galaxy
# 5. Testing roles

# %%
# %%ai $MODEL
# Ansible best practices:
# 1. Inventory organization
# 2. Variable precedence
# 3. Secret management (Vault)
# 4. Error handling
# 5. CI/CD integration

# %% [markdown]
# ---
#
# ## Summary
#
# Covered configuration management:
# - CM concepts
# - Ansible basics
# - Playbooks
# - Roles
# - Best practices
#
# ---
