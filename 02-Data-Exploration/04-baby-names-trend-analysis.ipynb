# %% [markdown]
# # 👶 Baby Names - Cultural Trends & Predictive Analytics
# ## Text Mining, Trend Forecasting, Network Analysis & Phonetic Clustering
#
# **Data:** `~/lab/data/CSVs/Popular_Baby_Names.csv`
#
# ### Exotic Techniques:
# - 📊 Animated race bar chart (name popularity over time)
# - 🔤 Phonetic clustering (names that sound similar)
# - 📈 ARIMA forecasting for name trends
# - 🌐 Name similarity network using edit distance
# - 🎨 Sunburst charts for hierarchical name patterns
# - 📉 Rise and fall trajectory analysis
# - 🎯 Trendsetter detection (early adoption names)
# - 🌊 Wavelettransform for cyclical name patterns

# %% [markdown]
# ## 1. Load & Explore

# %% [markdown]
# ## 2. Animated Racing Bar Chart

# %% [markdown]
# ## 3. Name Similarity Network

# %% [markdown]
# ## 4. Trend Lifecycle Analysis

# %% [markdown]
# ## 5. Phonetic Clustering

# %% [markdown]
# ## 6. Name Forecasting with ARIMA

# %% [markdown]
# ## 7. Gender Trend Analysis

# %% [markdown]
# ## 8. Name Length & Complexity Evolution

# %% [markdown]
# ## 9. Cultural Influence Detection

# %% [markdown]
# ## 10. Predictive Model: Will a Name Trend?

# %% [markdown]
# ## 11. Interactive Name Explorer Dashboard
