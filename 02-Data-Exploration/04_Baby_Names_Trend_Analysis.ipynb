# %% [markdown]
# # 👶 Baby Names - Cultural Trends & Predictive Analytics
# ## Text Mining, Trend Forecasting, Network Analysis & Phonetic Clustering
#
# **Data:** `~/lab/data/CSVs/Popular_Baby_Names.csv`
#
# ### Exotic Techniques:
# - 📊 Animated race bar chart (name popularity over time)
# - 🔤 Phonetic clustering (names that sound similar)
# - 📈 ARIMA forecasting for name trends
# - 🌐 Name similarity network using edit distance
# - 🎨 Sunburst charts for hierarchical name patterns
# - 📉 Rise and fall trajectory analysis
# - 🎯 Trendsetter detection (early adoption names)
# - 🌊 Wavelettransform for cyclical name patterns

# %% [markdown]
# ## 1. Load & Explore

# %%
# %%calliope ask gpto --format code
# Load ~/lab/data/CSVs/Popular_Baby_Names.csv
#
# Clean column names.
# Display:
# - Shape and columns
# - Years covered
# - Unique name count
# - Gender distribution
# - Top 20 most common names overall
# - Sample of data
#
# Store as 'names_df'.

# %% [markdown]
# ## 2. Animated Racing Bar Chart

# %%
# %%calliope ask anthropic-chat:claude-opus-4-20250514 --format code
# Using names_df:
#
# Create animated racing bar chart:
# 1. For each year, get top 15 names
# 2. Create plotly bar_chart_race animation:
#    - X-axis: Count/rank
#    - Y-axis: Names
#    - Animation frame: Year
#    - Color by gender or keep consistent per name
# 3. Add smooth transitions
# 4. Show year ticker
# 5. Add play/pause and speed controls
# 6. Highlight names entering/leaving top 15
#
# Make it visually engaging with smooth animations.

# %% [markdown]
# ## 3. Name Similarity Network

# %%
# %%calliope ask openai-chat:gpt-5 --format code
# Using names_df:
#
# Build network of similar names:
# 1. Take top 100 most popular names
# 2. Calculate pairwise similarity using:
#    - Levenshtein (edit) distance
#    - Phonetic similarity (soundex or metaphone)
# 3. Create edges for names with similarity > threshold
# 4. Use networkx for graph
# 5. Apply community detection (Louvain algorithm)
# 6. Visualize with plotly network graph:
#    - Node size = popularity
#    - Node color = community
#    - Edge width = similarity strength
#    - Interactive hover
# 7. Label detected communities with themes
#
# Print interesting name clusters found.

# %% [markdown]
# ## 4. Trend Lifecycle Analysis

# %%
# %%calliope ask gemini:gemini-2.5-pro --format code
# Using names_df:
#
# Analyze name lifecycle patterns:
# 1. For each name, calculate:
#    - Rise phase (years from first appearance to peak)
#    - Peak year and value
#    - Fall phase (years from peak to decline)
#    - Longevity (total years in dataset)
# 2. Classify names into categories:
#    - Timeless (consistent popularity)
#    - Trendy (quick rise and fall)
#    - Emerging (currently rising)
#    - Declining (past peak)
# 3. Create visualizations:
#    - Scatter: rise_speed vs longevity
#    - Examples of each category (line plots)
#    - Distribution of lifecycle types
# 4. Identify fastest rising and falling names
#
# Store lifecycle metrics in new dataframe.

# %% [markdown]
# ## 5. Phonetic Clustering

# %%
# %%calliope ask anthropic-chat:claude-sonnet-4-5-20250929 --format code
# Using names_df:
#
# Group names by sound:
# 1. Apply phonetic algorithm (Soundex, Metaphone, or Double Metaphone)
# 2. Group names with same phonetic code
# 3. Analyze patterns:
#    - Which sounds are most popular?
#    - How do phonetic trends change over time?
# 4. Create sunburst visualization:
#    - Inner ring: Phonetic group
#    - Outer ring: Actual names
#    - Size: Popularity
# 5. Interactive hover showing:
#    - Phonetic code
#    - Names in group
#    - Total count
#
# Identify most common phonetic patterns.

# %% [markdown]
# ## 6. Name Forecasting with ARIMA

# %%
# %%calliope ask openai-chat:gpt-4o --format code
# Using names_df:
#
# Forecast popularity for top 10 current names:
# 1. For each name, create time series of yearly counts
# 2. Fit ARIMA model (or use simple exponential smoothing)
# 3. Forecast next 5 years
# 4. Create subplot grid (2x5):
#    - Each subplot = one name
#    - Historical data + forecast with confidence intervals
# 5. Calculate forecast metrics
# 6. Identify which names are predicted to:
#    - Continue rising
#    - Peak soon
#    - Decline
#
# Print forecast summary for each name.

# %% [markdown]
# ## 7. Gender Trend Analysis

# %%
# %%calliope ask cohere:command-r-plus-08-2024 --format code
# Using names_df with gender information:
#
# Analyze gender-related naming trends:
# 1. Find unisex names (used for both genders)
# 2. Calculate gender ratio evolution over time
# 3. Identify names that switched dominant gender
# 4. Create visualizations:
#    - Stacked area chart: gender distribution over time
#    - Alluvial diagram: gender flow for specific names
#    - Scatter: gender_ratio vs popularity
# 5. Analyze letter patterns by gender:
#    - Which starting letters are more common for each gender?
#    - Which ending letters?
# 6. Create heatmap: first_letter x last_letter x gender
#
# Print interesting findings about gender patterns.

# %% [markdown]
# ## 8. Name Length & Complexity Evolution

# %%
# %%calliope ask gemini:gemini-2.0-flash --format code
# Using names_df:
#
# Analyze name characteristics over time:
# 1. Calculate for each name:
#    - Length (characters)
#    - Syllable count (estimate using vowel groups)
#    - Vowel-to-consonant ratio
#    - Uniqueness score (inverse of frequency)
# 2. Aggregate by year
# 3. Create time series plots:
#    - Average name length over years
#    - Average syllables
#    - Vowel ratio trend
#    - Diversity index (Shannon entropy)
# 4. Statistical tests:
#    - Are names getting shorter/longer? (trend test)
#    - Are they getting more/less diverse?
# 5. Create correlation matrix of name features
#
# Print trends and correlations found.

# %% [markdown]
# ## 9. Cultural Influence Detection

# %%
# %%calliope ask mistralai:mistral-large-latest --format code
# Using names_df:
#
# Detect sudden popularity spikes (potential cultural events):
# 1. Calculate year-over-year growth rate for each name
# 2. Identify names with:
#    - Sudden spikes (>100% growth in one year)
#    - Sustained increases (5+ years of growth)
#    - Viral names (went from obscure to top 100 quickly)
# 3. Create visualization:
#    - Timeline with spike annotations
#    - Highlight potential causes (note years of major movies, celebrities, events)
# 4. Clustering analysis:
#    - Group names by spike timing
#    - Find cohorts that rose together
# 5. Create interactive plot:
#    - Click on spike to see name details
#    - Show similar names that spiked at same time
#
# List top 20 biggest name spikes with years.

# %% [markdown]
# ## 10. Predictive Model: Will a Name Trend?

# %%
# %%calliope ask anthropic-chat:claude-3-7-sonnet-20250219 --format code
# Using names_df:
#
# Build classifier to predict if a name will become trendy:
# 1. Engineer features from name characteristics:
#    - Length, syllables, vowel ratio
#    - Phonetic properties
#    - Starting/ending letters
#    - Similarity to currently popular names
# 2. Label names as "trendy" if they had rapid growth
# 3. Train simple classifier (logistic regression or random forest)
# 4. Evaluate with cross-validation
# 5. Feature importance analysis:
#    - What makes a name likely to trend?
# 6. Apply model to current low-popularity names
# 7. Predict which obscure names might become popular
#
# Print model metrics and top 20 predicted future trends.

# %% [markdown]
# ## 11. Interactive Name Explorer Dashboard

# %%
# %%calliope ask gpto --format code
# Create comprehensive interactive dashboard:
#
# 1. Use ipywidgets for controls:
#    - Text input: Enter name
#    - Dropdowns: Gender, year range
#    - Sliders: Min/max popularity
# 2. Dashboard panels:
#    - Panel 1: Name trend line over time
#    - Panel 2: Similar names (network)
#    - Panel 3: Phonetic relatives
#    - Panel 4: Rank history
#    - Panel 5: Forecast
# 3. Update all panels dynamically on input change
# 4. Add comparison mode: compare 2-3 names side by side
# 5. Export selected name report as HTML
#
# Make it fully interactive and user-friendly.
