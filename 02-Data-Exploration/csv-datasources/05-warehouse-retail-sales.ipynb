# %% [markdown]
# # Warehouse & Retail Sales Analysis
#
# **Category:** 02-Data-Exploration / CSV Datasources
# **Dataset:** Warehouse_and_Retail_Sales.csv (27MB)
#
# ---
#
# ## Dataset Overview
# - Sales transactions with product, location, time
# - Ideal for: Time series forecasting, demand planning, inventory optimization

# %%
# %pip install -q pandas numpy matplotlib seaborn

CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

plt.style.use('seaborn-v0_8-whitegrid')
DATA_PATH = Path.home() / 'lab' / 'data' / 'CSVs' / 'Warehouse_and_Retail_Sales.csv'

# %%
df = pd.read_csv(DATA_PATH)
print(f"Loaded {len(df):,} sales records")
df.head()

# %%
df.info()

# %%
# Parse date if available
date_cols = [c for c in df.columns if 'date' in c.lower() or 'time' in c.lower()]
print(f"Date columns: {date_cols}")

# Basic statistics
df.describe()

# %%
# Sales by category (if available)
cat_cols = [c for c in df.columns if 'category' in c.lower() or 'type' in c.lower() or 'product' in c.lower()]
if cat_cols:
    for col in cat_cols[:2]:
        print(f"\n{col}:")
        print(df[col].value_counts().head(10))

# %%
# %%ai $MODEL
# For retail/warehouse sales data analysis:
#
# 1. What are the most important KPIs to track?
# 2. How can we identify seasonal patterns?
# 3. What forecasting methods work best for retail demand?
# 4. How does inventory optimization relate to sales forecasting?

# %% [markdown]
# ---
#
# ## Summary
#
# This notebook explored warehouse/retail sales data for:
# - Sales distribution analysis
# - Category breakdown
# - Temporal patterns (if dates available)
#
# **See also:** `12-Time-Series/` for forecasting examples
#
# ---
