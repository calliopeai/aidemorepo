# %% [markdown]
# # Popular Baby Names Analysis
#
# **Category:** 02-Data-Exploration / CSV Datasources
# **Dataset:** Popular_Baby_Names.csv (2.7MB)
# **Source:** NYC Open Data
#
# ---
#
# ## Dataset Overview
# - Baby names by year, gender, ethnicity
# - NYC births data
# - Ideal for: Trend analysis, cultural patterns, demographic insights

# %%
# %pip install -q pandas numpy matplotlib seaborn

CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

plt.style.use('seaborn-v0_8-whitegrid')
DATA_PATH = Path.home() / 'lab' / 'data' / 'CSVs' / 'Popular_Baby_Names.csv'

# %%
df = pd.read_csv(DATA_PATH)
print(f"Loaded {len(df):,} name records")
df.head(10)

# %%
# Clean column names
df.columns = df.columns.str.strip().str.lower().str.replace("'", "").str.replace(" ", "_")
print(f"Columns: {df.columns.tolist()}")

# %%
# Top names overall
name_col = [c for c in df.columns if 'name' in c][0]
count_col = [c for c in df.columns if 'count' in c][0]

top_names = df.groupby(name_col)[count_col].sum().sort_values(ascending=False).head(20)

plt.figure(figsize=(12, 8))
top_names.plot(kind='barh', color='steelblue')
plt.title('Top 20 Baby Names (All Years)')
plt.xlabel('Total Count')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# Names by gender
gender_col = [c for c in df.columns if 'gender' in c][0]

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

for idx, gender in enumerate(df[gender_col].unique()[:2]):
    gender_data = df[df[gender_col] == gender]
    top = gender_data.groupby(name_col)[count_col].sum().sort_values(ascending=False).head(10)
    axes[idx].barh(top.index, top.values, color='pink' if 'F' in gender else 'lightblue')
    axes[idx].set_title(f'Top 10 Names - {gender}')
    axes[idx].invert_yaxis()

plt.tight_layout()
plt.show()

# %%
# %%ai $MODEL
# Analyzing baby name trends:
#
# 1. What cultural factors influence baby name popularity?
# 2. How do naming patterns differ across ethnic groups?
# 3. What causes names to suddenly spike or decline in popularity?
# 4. Are there any predictive patterns for "the next popular name"?

# %% [markdown]
# ---
#
# ## Summary
#
# This notebook analyzed baby name trends including:
# - Overall most popular names
# - Gender-based patterns
# - Temporal trends
#
# ---
