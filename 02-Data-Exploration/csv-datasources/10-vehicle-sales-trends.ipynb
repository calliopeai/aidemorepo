# %% [markdown]
# # MVA Vehicle Sales Analysis
#
# **Category:** 02-Data-Exploration / CSV Datasources
# **Dataset:** MVA_Vehicle_Sales_Counts_by_Month_for_Calendar_Year_2002_through_February_2025.csv (12KB)
#
# ---
#
# ## Dataset Overview
# - Monthly vehicle sales counts
# - 20+ years of historical data
# - Ideal for: Time series analysis, economic indicators

# %%
# %pip install -q pandas numpy matplotlib seaborn

CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

plt.style.use('seaborn-v0_8-whitegrid')
DATA_PATH = Path.home() / 'lab' / 'data' / 'CSVs' / 'MVA_Vehicle_Sales_Counts_by_Month_for_Calendar_Year_2002_through_February_2025.csv'

# %%
df = pd.read_csv(DATA_PATH)
print(f"Loaded {len(df):,} records")
df.head()

# %%
# Look at structure
df.info()
print(f"\nYears covered: {df['Year'].min()} - {df['Year'].max()}" if 'Year' in df.columns else "Check column names")

# %%
# %%ai $MODEL
# For vehicle sales analysis:
#
# 1. What economic indicators correlate with auto sales?
# 2. How did the 2008 recession and COVID affect sales?
# 3. What seasonal patterns exist in car buying?
# 4. How can dealerships use this data for inventory planning?

# %% [markdown]
# ---
#
# ## Summary
#
# This notebook explored vehicle sales trends for:
# - Long-term market patterns
# - Economic cycle impacts
# - Seasonal variations
#
# ---
