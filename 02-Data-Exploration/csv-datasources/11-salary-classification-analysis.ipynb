# %% [markdown]
# # Salary by Job Classification Analysis
#
# **Category:** 02-Data-Exploration / CSV Datasources
# **Dataset:** Average_Salary_by_Job_Classification.csv (17KB)
#
# ---
#
# ## Dataset Overview
# - Salary data by job classification
# - Useful for: HR analytics, compensation benchmarking

# %%
# %pip install -q pandas numpy matplotlib seaborn

CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

plt.style.use('seaborn-v0_8-whitegrid')
DATA_PATH = Path.home() / 'lab' / 'data' / 'CSVs' / 'Average_Salary_by_Job_Classification.csv'

# %%
df = pd.read_csv(DATA_PATH)
print(f"Loaded {len(df):,} job classifications")
df.head(10)

# %%
df.info()
df.describe()

# %%
# Find salary column and visualize
salary_cols = [c for c in df.columns if 'salary' in c.lower() or 'wage' in c.lower() or 'pay' in c.lower()]
print(f"Salary-related columns: {salary_cols}")

# %%
# %%ai $MODEL
# For salary classification analysis:
#
# 1. What factors determine job classification and pay grades?
# 2. How can organizations ensure pay equity?
# 3. What's the difference between salary compression and inversion?
# 4. How do market rates influence public sector compensation?

# %% [markdown]
# ---
#
# ## Summary
#
# This notebook explored salary classification data for:
# - Compensation distribution
# - Job classification analysis
# - Pay equity considerations
#
# ---
