# %% [markdown]
# # Motor Fuel Sales Analysis
#
# **Category:** 02-Data-Exploration / CSV Datasources
# **Dataset:** Monthly_Motor_Fuel_Sales_Reported_by_States.csv (1.2MB)
# **Source:** FHWA
#
# ---
#
# ## Dataset Overview
# - State-level monthly motor fuel sales
# - Multiple fuel types
# - Historical trends for energy analysis

# %%
# %pip install -q pandas numpy matplotlib seaborn

CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

plt.style.use('seaborn-v0_8-whitegrid')
DATA_PATH = Path.home() / 'lab' / 'data' / 'CSVs' / 'Monthly_Motor_Fuel_Sales_Reported_by_States__Selected_Data_from_FHWA_Monthly_Motor_Fuel_Report.csv'

# %%
df = pd.read_csv(DATA_PATH)
print(f"Loaded {len(df):,} records")
df.head()

# %%
df.info()

# %%
# %%ai $MODEL
# Analyzing motor fuel sales trends:
#
# 1. What factors drive gasoline demand?
# 2. How has the COVID-19 pandemic affected fuel sales?
# 3. What's the relationship between fuel prices and consumption?
# 4. How might EV adoption impact future fuel sales?

# %% [markdown]
# ---
#
# ## Summary
#
# This notebook explored motor fuel sales data for:
# - State-level consumption patterns
# - Temporal trends
# - Energy transition analysis
#
# ---
