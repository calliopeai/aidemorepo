# %% [markdown]
# # Nutrition, Physical Activity & Obesity Analysis
#
# **Category:** 02-Data-Exploration / CSV Datasources
# **Dataset:** Nutrition__Physical_Activity__and_Obesity_-_BRFSS.csv (35MB)
# **Source:** CDC BRFSS
#
# ---
#
# ## Dataset Overview
# - Behavioral risk factor surveillance system data
# - State-level nutrition and physical activity metrics
# - Obesity rates and health behaviors

# %%
# %pip install -q pandas numpy matplotlib seaborn

CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

plt.style.use('seaborn-v0_8-whitegrid')
DATA_PATH = Path.home() / 'lab' / 'data' / 'CSVs' / 'Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv'

# %%
df = pd.read_csv(DATA_PATH, low_memory=False)
print(f"Loaded {len(df):,} records")
df.head()

# %%
# Questions/Topics covered
print("Topics covered:")
if 'Question' in df.columns:
    for q in df['Question'].unique()[:15]:
        print(f"  - {q}")

# %%
# %%ai $MODEL
# For nutrition and obesity surveillance data:
#
# 1. What are the key indicators of population health?
# 2. How do physical activity levels correlate with obesity rates?
# 3. What geographic patterns exist in obesity prevalence?
# 4. How can public health interventions use this data?

# %% [markdown]
# ---
#
# ## Summary
#
# This notebook explored nutrition and obesity data from BRFSS for:
# - Health behavior metrics
# - State-level comparisons
# - Trend analysis
#
# ---
