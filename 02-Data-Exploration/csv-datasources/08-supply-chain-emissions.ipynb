# %% [markdown]
# # Supply Chain GHG Emission Factors Analysis
#
# **Category:** 02-Data-Exploration / CSV Datasources
# **Dataset:** SupplyChainGHGEmissionFactors_v1.3.0_NAICS_CO2e_USD2022.csv (121KB)
# **Source:** EPA
#
# ---
#
# ## Dataset Overview
# - Industry-level emission factors by NAICS code
# - kg CO2e per dollar of output
# - For Scope 3 emissions calculations

# %%
# %pip install -q pandas numpy matplotlib seaborn

CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

plt.style.use('seaborn-v0_8-whitegrid')
DATA_PATH = Path.home() / 'lab' / 'data' / 'CSVs' / 'SupplyChainGHGEmissionFactors_v1.3.0_NAICS_CO2e_USD2022.csv'

# %%
df = pd.read_csv(DATA_PATH)
print(f"Loaded {len(df):,} industry emission factors")
df.head(10)

# %%
# Find emission factor column
emission_cols = [c for c in df.columns if 'CO2' in c.upper() or 'emission' in c.lower()]
print(f"Emission columns: {emission_cols}")
df.info()

# %%
# %%ai $MODEL
# Explain supply chain emissions:
#
# 1. What are Scope 1, 2, and 3 emissions?
# 2. How are emission factors used in carbon accounting?
# 3. Which industries typically have the highest emissions per dollar?
# 4. How can companies use this data to reduce their carbon footprint?

# %% [markdown]
# ---
#
# ## Summary
#
# This notebook explored EPA supply chain emission factors for:
# - Industry emission intensities
# - NAICS code mapping
# - Scope 3 emissions calculations
#
# ---
