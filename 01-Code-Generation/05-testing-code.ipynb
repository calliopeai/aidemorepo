# %% [markdown]
# # AI-Generated Unit Tests
#
# **Category:** 01-Code-Generation
# **Topic:** Generating test suites with AI
#
# ---
#
# ## Learning Objectives
# - Generate pytest test cases
# - Create test fixtures
# - Implement parameterized tests
# - Mock external dependencies

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Given this function, generate comprehensive pytest tests:
#
# ```python
# def calculate_shipping(weight: float, distance: int, express: bool = False) -> float:
#     base_rate = 5.0
#     weight_rate = 0.5 * weight
#     distance_rate = 0.1 * distance
#     total = base_rate + weight_rate + distance_rate
#     if express:
#         total *= 1.5
#     return round(total, 2)
# ```
#
# Include: edge cases, boundary values, error conditions

# %%
# %%ai $MODEL
# Create pytest fixtures for database testing:
# - Database connection fixture
# - Sample data fixture
# - Cleanup/teardown fixture
# - Session-scoped vs function-scoped
# - Fixture dependencies

# %%
# %%ai $MODEL
# Generate parameterized tests for a password validator:
#
# ```python
# def validate_password(password: str) -> tuple[bool, list[str]]:
#     # Returns (is_valid, list_of_errors)
#     pass
# ```
#
# Rules: min 8 chars, 1 uppercase, 1 lowercase, 1 digit, 1 special char
# Use pytest.mark.parametrize with multiple test cases

# %%
# %%ai $MODEL
# Generate tests with mocking for an API client:
#
# ```python
# class WeatherClient:
#     def __init__(self, api_key: str):
#         self.api_key = api_key
#
#     def get_temperature(self, city: str) -> float:
#         response = requests.get(f"https://api.weather.com/{city}")
#         return response.json()["temperature"]
# ```
#
# Mock the requests library, test success and failure cases

# %%
# %%ai $MODEL
# Create integration test patterns:
# - Test a FastAPI endpoint with TestClient
# - Database integration tests
# - Test with Docker containers (testcontainers)
# - API contract testing
# - Include setup and teardown

# %% [markdown]
# ---
#
# ## Summary
#
# Generated testing patterns:
# - Unit tests with pytest
# - Fixtures for setup/teardown
# - Parameterized tests
# - Mocking external services
# - Integration testing
#
# ---
