# %% [markdown]
# # AI-Assisted SQL Generation
#
# **Category:** 01-Code-Generation
# **Topic:** Generating SQL queries with AI
#
# ---
#
# ## Learning Objectives
# - Generate complex SQL queries
# - Create database schemas
# - Write stored procedures
# - Optimize query performance

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Generate a normalized database schema for an online bookstore:
# - Books, Authors, Publishers, Categories
# - Customers, Orders, Order Items
# - Reviews and Ratings
# - Include primary keys, foreign keys, indexes
# - Use appropriate data types

# %%
# %%ai $MODEL
# Generate these analytical SQL queries:
#
# 1. Top 10 best-selling books with author info
# 2. Monthly revenue trend for the past year
# 3. Customer lifetime value calculation
# 4. Books with highest average rating (min 10 reviews)
# 5. Category performance comparison

# %%
# %%ai $MODEL
# Generate advanced SQL with window functions:
# - Running total of sales by month
# - Rank customers by purchase amount
# - Moving average of daily orders
# - Year-over-year growth comparison
# - Percentile ranking of products

# %%
# %%ai $MODEL
# Create a stored procedure for order processing:
# - Check inventory availability
# - Calculate total with tax and shipping
# - Create order and order items
# - Update inventory
# - Handle errors with transactions
# - Return order confirmation

# %%
# %%ai $MODEL
# Optimize this slow query and explain the improvements:
#
# ```sql
# SELECT c.name, COUNT(*) as order_count, SUM(o.total) as total_spent
# FROM customers c, orders o, order_items oi, products p
# WHERE c.id = o.customer_id
# AND o.id = oi.order_id
# AND oi.product_id = p.id
# AND p.category = 'Electronics'
# AND o.order_date > '2023-01-01'
# GROUP BY c.name
# ORDER BY total_spent DESC
# ```
#
# Suggest indexes and query rewrites.

# %% [markdown]
# ---
#
# ## Summary
#
# Generated SQL components:
# - Database schema design
# - Analytical queries
# - Window functions
# - Stored procedures
# - Query optimization
#
# ---
