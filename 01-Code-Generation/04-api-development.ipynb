# %% [markdown]
# # AI-Assisted API Development
#
# **Category:** 01-Code-Generation
# **Topic:** Generating REST APIs with AI
#
# ---
#
# ## Learning Objectives
# - Generate FastAPI endpoints
# - Create data validation with Pydantic
# - Implement CRUD operations
# - Add authentication patterns

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Generate a FastAPI application with:
# - User model with Pydantic validation
# - CRUD endpoints (Create, Read, Update, Delete)
# - In-memory storage for demo
# - Proper HTTP status codes
# - OpenAPI documentation annotations

# %%
# %%ai $MODEL
# Create Pydantic models for an e-commerce API:
# - Product (id, name, price, description, category, stock)
# - Order (id, user_id, products, total, status, created_at)
# - Customer (id, email, name, address)
# - Include validation (email format, price > 0, etc.)
# - Add example values for documentation

# %%
# %%ai $MODEL
# Generate JWT authentication for FastAPI:
# - Login endpoint returning access token
# - Token verification dependency
# - Protected route example
# - Token refresh mechanism
# - Password hashing with bcrypt

# %%
# %%ai $MODEL
# Create API error handling patterns:
# - Custom exception classes
# - Exception handlers for FastAPI
# - Standardized error response format
# - Logging integration
# - Example: validation, not found, unauthorized errors

# %%
# %%ai $MODEL
# Generate API rate limiting middleware:
# - Token bucket algorithm
# - Per-user or per-IP limiting
# - Redis-based distributed limiting
# - Custom rate limit headers
# - FastAPI middleware integration

# %% [markdown]
# ---
#
# ## Summary
#
# Generated API components:
# - FastAPI CRUD endpoints
# - Pydantic data models
# - JWT authentication
# - Error handling patterns
# - Rate limiting middleware
#
# ---
