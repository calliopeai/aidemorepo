# %% [markdown]
# # AI-Generated Documentation
#
# **Category:** 01-Code-Generation
# **Topic:** Creating documentation with AI
#
# ---
#
# ## Learning Objectives
# - Generate docstrings and type hints
# - Create API documentation
# - Write README files
# - Produce architecture docs

# %%
CLAUDE = "anthropic-chat:claude-sonnet-4-5-20250929"
MODEL = CLAUDE

# %%
# %%ai $MODEL
# Add comprehensive docstrings and type hints to this code:
#
# ```python
# class DataProcessor:
#     def __init__(self, config):
#         self.config = config
#         self.cache = {}
#
#     def load_data(self, source, format='csv'):
#         if source in self.cache:
#             return self.cache[source]
#         data = self._read_file(source, format)
#         self.cache[source] = data
#         return data
#
#     def transform(self, data, operations):
#         result = data.copy()
#         for op in operations:
#             result = op(result)
#         return result
# ```
#
# Use Google-style docstrings with Args, Returns, Raises.

# %%
# %%ai $MODEL
# Generate OpenAPI/Swagger documentation for this FastAPI app:
#
# ```python
# @app.post("/users")
# async def create_user(user: UserCreate):
#     ...
#
# @app.get("/users/{user_id}")
# async def get_user(user_id: int):
#     ...
#
# @app.put("/users/{user_id}")
# async def update_user(user_id: int, user: UserUpdate):
#     ...
# ```
#
# Include response models, status codes, and examples.

# %%
# %%ai $MODEL
# Generate a README.md template for a Python project:
#
# Project: data-pipeline-toolkit
# - ETL framework for data processing
# - Supports CSV, JSON, Parquet
# - Includes data validation
# - Has scheduling capabilities
#
# Include: badges, installation, quickstart, configuration, examples

# %%
# %%ai $MODEL
# Create architecture documentation for a microservices system:
#
# Services:
# - API Gateway (Kong)
# - User Service (FastAPI + PostgreSQL)
# - Order Service (FastAPI + MongoDB)
# - Notification Service (Celery + Redis)
# - Payment Service (gRPC)
#
# Include: component diagram (mermaid), data flow, API contracts

# %%
# %%ai $MODEL
# Generate inline code comments for this complex algorithm:
#
# ```python
# def find_max_profit(prices):
#     if len(prices) < 2:
#         return 0
#
#     min_price = prices[0]
#     max_profit = 0
#
#     for price in prices[1:]:
#         potential_profit = price - min_price
#         max_profit = max(max_profit, potential_profit)
#         min_price = min(min_price, price)
#
#     return max_profit
# ```
#
# Explain the algorithm logic and time/space complexity.

# %% [markdown]
# ---
#
# ## Summary
#
# Generated documentation types:
# - Docstrings with type hints
# - OpenAPI/Swagger specs
# - README templates
# - Architecture documentation
# - Code comments
#
# ---
