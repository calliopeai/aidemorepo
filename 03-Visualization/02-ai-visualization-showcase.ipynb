# %% [markdown]
# # 🎨 AI-Powered Visualization Showcase
# ## Create Stunning Visualizations with Natural Language Commands
#
# This notebook demonstrates the power of using Jupyter AI (`%%calliope` magic commands) to generate beautiful, complex visualizations using simple natural language requests.
#
# ### What You'll See:
# - 📊 Interactive Plotly visualizations
# - 🎭 3D animations and attractors
# - 🌊 Time-series and animated plots
# - 📈 Statistical visualizations with Seaborn
# - 🎯 Real-world data analysis examples
#
# ### How It Works:
# Simply ask the AI to "show me a cool viz" and different models will create unique, sophisticated visualizations!
#
# ---

# %% [markdown]
# ## 🤖 Available AI Models
#
# First, let's see what AI models are available in your environment:

# %%
# =============================================================================
# AUTO-INSTALL DEPENDENCIES
# Run this cell to scan the notebook and install required packages
# =============================================================================
# %%calliope ask claude --format code
Scan this notebook for all Python imports and library dependencies.
Generate a shell script that:
1. Checks if each required package is installed
2. Installs any missing packages using pip
Output only the executable shell commands, no explanations.

# %%
# %calliope list-models

# %% [markdown]
# ## 📊 Example 1: Interactive Gapminder Bubble Chart (Gemini 2.5 Pro)
#
# Let's ask Gemini to create an interactive visualization:

# %%
# %%calliope ask gemini:gemini-2.5-pro --format code
# show me a really cool interactive viz in jupyter

# %% [markdown]
# ## 🎨 Example 2: Simple Scatter Plot (GPT-4o)
#
# Let's see what GPT-4o creates with the same request:

# %%
# %%calliope ask gpto --format code
# show me a cool viz in jupyter

# %% [markdown]
# ## 🌀 Example 3: Lorenz Attractor (GPT-5)
#
# Ask GPT-5 for something cool and watch it create a beautiful 3D Lorenz attractor:

# %%
# %%calliope ask openai-chat:gpt-5 --format code
# show me a cool viz in jupyter

# %% [markdown]
# ## 🌌 Example 4: Animated Spiral Galaxy (Claude Sonnet 4.5)
#
# Claude creates a stunning animated spiral visualization:

# %%
# %%calliope ask anthropic-chat:claude-sonnet-4-5-20250929 --format code
# show me a cool viz in jupyter

# %% [markdown]
# ## 📈 Example 5: Real Data Analysis - Diabetes Dataset
#
# Now let's work with real data. Ask AI to load and analyze a dataset:

# %%
# %%calliope ask anthropic-chat:claude-sonnet-4-5-20250929 --format code
# Load the diabetes dataset from ~/lab/data/CSVs/diabetes_all_2016.csv
# and create a comprehensive analysis with multiple visualizations

# %% [markdown]
# ## 🎯 Example 6: Statistical Visualizations
#
# Let's create a suite of statistical plots:

# %%
# %%calliope ask gpto --format code
# Create a 2x3 grid of statistical visualizations using seaborn:
# 1. Distribution plot
# 2. Box plot
# 3. Violin plot
# 4. Scatter plot with regression
# 5. Heatmap
# 6. Pair plot (subset)
# Use the iris dataset and make it visually appealing

# %% [markdown]
# ## 🌊 Example 7: 3D Surface Plot
#
# Create a beautiful 3D surface visualization:

# %%
# %%calliope ask gemini:gemini-2.5-pro --format code
# Create a stunning 3D surface plot with plotly using a mathematical function.
# Make it interactive with custom colorscale and lighting.

# %% [markdown]
# ## 🎭 Example 8: Animated Line Chart
#
# Generate an animated visualization that evolves over time:

# %%
# %%calliope ask openai-chat:gpt-5 --format code
# Create an animated line chart using matplotlib that shows
# multiple sine waves with different frequencies and phases.
# Make it visually striking with a dark theme.

# %% [markdown]
# ## 🔥 Example 9: Heatmap with Hierarchical Clustering
#
# Create a clustered heatmap with dendrograms:

# %%
# %%calliope ask anthropic-chat:claude-opus-4-20250514 --format code
# Create a clustered heatmap (clustermap) with seaborn.
# Use synthetic data representing gene expression across samples.
# Include dendrograms and make it publication-quality.

# %% [markdown]
# ## 🎪 Example 10: Network Graph Visualization
#
# Visualize a network graph with NetworkX and Matplotlib:

# %%
# %%calliope ask gpto --format code
# Create an interactive network graph visualization using plotly and networkx.
# Generate a random scale-free network (Barabási-Albert model).
# Color nodes by degree centrality and size by betweenness centrality.

# %% [markdown]
# ---
#
# ## 🤔 Model Comparison
#
# ### Observations:
#
# | Model | Strengths | Best For |
# |-------|-----------|----------|
# | **GPT-5** | Sophisticated, complex visualizations | 3D plots, mathematical art, animations |
# | **GPT-4o** | Balanced, reliable | General purpose, statistical plots |
# | **Claude Sonnet 4.5** | Creative, artistic | Animations, custom styling, novel approaches |
# | **Gemini 2.5 Pro** | Fast, practical | Interactive dashboards, Plotly charts |
# | **Claude Opus 4** | Publication-quality | Academic papers, detailed heatmaps |
#
# ### Pro Tips:
#
# 1. **Be Specific**: The more detail in your request, the better the result
# 2. **Iterate**: Start simple, then ask for refinements
# 3. **Mix Models**: Different models excel at different visualization types
# 4. **Request Interactivity**: Ask for "interactive" or "with plotly" for web-ready charts
# 5. **Specify Aesthetics**: Mention color schemes, themes, and styling preferences
#
# ---
#
# ## 🎓 Your Turn!
#
# Try these prompts below:

# %%
# %%calliope ask gpto --format code
# # Try your own prompt here!
# # Examples:
# # - Create a sankey diagram showing data flow
# # - Make a choropleth map of world population
# # - Generate a treemap visualization
# # - Create a waterfall chart
# # - Build a radar/spider chart

# %% [markdown]
# ## 🚀 Advanced: Combine with Data Analysis
#
# The real power comes from combining AI-generated visualizations with your own data analysis:

# %%
# Load your data
import pandas as pd

# Example: Load one of the CSV datasets
# df = pd.read_csv('~/lab/data/CSVs/your_dataset.csv')

# Then ask AI to visualize it:
# %%calliope ask gpto --format code
# Using the dataframe 'df', create 3 insightful visualizations
# that reveal patterns in the data

# %% [markdown]
# ---
#
# ## 📚 Related Resources
#
# ### Other Visualization Notebooks in This Repository:
# - **MathPlotLib.ipynb** - Deep dive into matplotlib features
# - **SeabornVizDemo.ipynb** - Statistical visualization masterclass
# - **Combined Plotly.ipynb** - Interactive plotly examples
# - **Lorenz Attractor Demo.ipynb** - Chaos theory visualization
#
# ### Advanced Analytics Notebooks:
# Check `~/lab/` for 12 notebooks with exotic techniques:
# - Time series analysis with Prophet & ARIMA
# - Geospatial visualizations (choropleth, hotspot maps)
# - Network analysis (PageRank, community detection)
# - ML interpretability (SHAP plots)
# - 130+ advanced examples!
#
# ### Documentation:
# - [Jupyter AI Docs](https://jupyter-ai.readthedocs.io/)
# - [Plotly Python](https://plotly.com/python/)
# - [Matplotlib Gallery](https://matplotlib.org/stable/gallery/)
# - [Seaborn Tutorial](https://seaborn.pydata.org/tutorial.html)
#
# ---
#
# **Happy visualizing! 🎨✨**
#
# *Remember: The best visualization is the one that tells your data's story most clearly!*
