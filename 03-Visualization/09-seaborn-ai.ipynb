# %%
# =============================================================================
# AUTO-INSTALL DEPENDENCIES
# Run this cell to scan the notebook and install required packages
# =============================================================================
# %%calliope ask claude --format code
Scan this notebook for all Python imports and library dependencies.
Generate a shell script that:
1. Checks if each required package is installed
2. Installs any missing packages using pip
Output only the executable shell commands, no explanations.

# %%
# %%calliope ask gpto --format code
# show me a cool 3d viz with seaborn
# Out:
# AI generated code inserted below &#11015;&#65039;

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Generate data
np.random.seed(42)
n_points = 100
x = np.random.normal(size=n_points)
y = np.random.normal(size=n_points)
z = x * y + np.random.normal(size=n_points)

# Create the figure
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Create a 3D scatter plot
scatter = ax.scatter(x, y, z, c=z, cmap='coolwarm', s=50)

# Add color bar which maps values to colors
cbar = plt.colorbar(scatter, ax=ax, pad=0.1)
cbar.set_label('Z value')

# Set labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Scatter Plot with Seaborn Style')

# Apply seaborn style
sns.set_style("whitegrid")

plt.show()
